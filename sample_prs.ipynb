# %% [markdown]
# # Choose random PRs
#
# Fetch all PRs merged between two dates
#
# Select a random subset of those PRs.
#
# Configure the following variables:
# * `FROM_DATE`
# * `TO_DATE`
# * `SAMPLE_SIZE`

# %%
import random
from operator import itemgetter
from typing import Dict
from django.conf import settings
import apps.patterns.github as gh

FROM_DATE="2021-01-28"
TO_DATE="2021-02-04"
SAMPLE_SIZE=50


def calculate_score(payload: Dict) -> float:
    base_score = 1
    commits_points = payload["commits"] * 10
    files_points = payload["changed_files"] * 10
    base_score += payload["additions"]
    base_score -= payload["deletions"]
    return base_score * commits_points + files_points
    
    
def calculate_score_v1(payload: Dict) -> float:
    return payload["commits"] + payload["changed_files"]

skipped_authors = [
    'sebastialonso', 'dmarquezlutfy', 'dvelez-jimenez',
    'helderthh', 'viktorvillalobos', 'susana-hernandez',
    'amontanezp', 'lbenitez000', 'fsobarzo'
]
github_repo = gh.get_repo()
pr_query = f"repo:{settings.BACKEND_REPO_SLUG} is:pr is:open draft:false created:{FROM_DATE}..{TO_DATE}"
print("Searching PR matching with parameters...")
found_prs = gh.search_issues_with_query(query=pr_query)

if len(found_prs) > SAMPLE_SIZE:
    found_prs = found_prs[:SAMPLE_SIZE]
    print(f"Found {len(found_prs)}, but will only fetch {SAMPLE_SIZE}")
else:
    print(f"Found {len(found_prs)}")

complete_prs = []
print("Fetching PRs...", end="")
for count, pr in enumerate(found_prs):
    print(f"{round(count/len(found_prs), 2)}", end="...")
    pull_request = github_repo.get_pull(pr.number)
    
    if pull_request.user.login in skipped_authors:
        continue
    if "experimental/" in pull_request.head.label or "canary/" in pull_request.head.label:
        continue

    payload = dict(
        title=pull_request.title,
        head=pull_request.head.label,
        number=pull_request.number,
        url=pull_request.html_url,
        commits=pull_request.commits,
        additions=pull_request.additions,
        deletions=pull_request.deletions,
        changed_files=pull_request.changed_files,
        merged_at=pull_request.merged_at,
        created_at=pull_request.created_at,
        updated_at=pull_request.updated_at,
        user=pull_request.user.login
    )
    payload["score"] = calculate_score_v1(payload)
    complete_prs.append(payload)
print()
print(f"Total: {len(found_prs)}")
prs = sorted(complete_prs, key=itemgetter('score'), reverse=True)
print(f"Selecting worst top-{SAMPLE_SIZE} (from {FROM_DATE} to {TO_DATE})")
print()
for pr in prs[:SAMPLE_SIZE]:
    print(f"{pr['head']} {pr['url']} ({pr['user']}) ({pr['score']})")
    print()
# Out:
# Searching PR matching with parameters...
# Found 44
# Fetching PRs...0.0...0.02...0.05...0.07...0.09...0.11...0.14...0.16...0.18...0.2...0.23...0.25...0.27...0.3...0.32...0.34...0.36...0.39...0.41...0.43...0.45...0.48...0.5...0.52...0.55...0.57...0.59...0.61...0.64...0.66...0.68...0.7...0.73...0.75...0.77...0.8...0.82...0.84...0.86...0.89...0.91...0.93...0.95...0.98...
# Total: 44
# Selecting worst top-50 (from 2021-01-28 to 2021-02-04)
# cornershop:feat/payroll/ch61553/create-cr-generic-payroll-including-tipping https://github.com/cornershop/cornershop-backend/pull/19306 (pgarcia14180) (24)
#
# cornershop:feat/ch59050/shopify-purolator https://github.com/cornershop/cornershop-backend/pull/19309 (pfariaz) (21)
#
# cornershop:chore/payroll/ch61254/create-colombian-generic-payroll-including-tipping https://github.com/cornershop/cornershop-backend/pull/19302 (pgarcia14180) (19)
#
# cornershop:feat/tms/ch58787/implement-new-assigner https://github.com/cornershop/cornershop-backend/pull/19339 (ivanACL) (18)
#
# cornershop:chore/payments/minor-refactor-logging-information-models https://github.com/cornershop/cornershop-backend/pull/19329 (LuisSanchez) (17)
#
# cornershop:feature/ch61545/add-ab-testing-support-for-new-landing-page https://github.com/cornershop/cornershop-backend/pull/19328 (antonio94js) (17)
#
# cornershop:chore/call_to_action https://github.com/cornershop/cornershop-backend/pull/19364 (alefer9) (16)
#
# cornershop:feature/ch60692/register-operational-rate-webhook https://github.com/cornershop/cornershop-backend/pull/19268 (juanpablos) (16)
#
# cornershop:feature/ch60926/add-fulfillment-info https://github.com/cornershop/cornershop-backend/pull/19369 (bixtope) (15)
#
# cornershop:debt/events/order-status-changed-event-refactor https://github.com/cornershop/cornershop-backend/pull/19256 (roalonso) (15)
#
# cornershop:feat/payroll/ch61392/make-generic-csv-payroll-to-send-a-csv-for-each-type https://github.com/cornershop/cornershop-backend/pull/19283 (pgarcia14180) (12)
#
# cornershop:chore/product-search/ch61269 https://github.com/cornershop/cornershop-backend/pull/19295 (xleninx) (11)
#
# cornershop:bug/ch51090/get_pending_receipts_improvements https://github.com/cornershop/cornershop-backend/pull/19286 (Javendanon) (11)
#
# cornershop:chore/ch61693/cast-values-from-internal-api https://github.com/cornershop/cornershop-backend/pull/19344 (jwllee) (10)
#
# cornershop:bug/ch61764/onboarding/fix-error-raised-when-shoppers-try-to-register https://github.com/cornershop/cornershop-backend/pull/19338 (yoyojlf) (10)
#
# cornershop:feat/security_event_view https://github.com/cornershop/cornershop-backend/pull/19332 (joacocruz6) (9)
#
# cornershop:chore/tipping/release-condition https://github.com/cornershop/cornershop-backend/pull/19311 (felipesuazo) (9)
#
# cornershop:chore/risk/activate-rule-engine-some-countries https://github.com/cornershop/cornershop-backend/pull/19262 (ngjonnathan) (9)
#
# cornershop:vuln/stores/dont-unfurl-new-store-lead-slack-notifications https://github.com/cornershop/cornershop-backend/pull/19272 (nixaraven) (8)
#
# cornershop:feat/crmcenter/query-builder https://github.com/cornershop/cornershop-backend/pull/19296 (knarf20) (7)
#
# cornershop:chore/risk/enable-ravelin-old-customers https://github.com/cornershop/cornershop-backend/pull/19348 (gruizmir) (6)
#
# cornershop:feat/internal-app-to-add-new-localities-migrations https://github.com/cornershop/cornershop-backend/pull/19334 (gsanhuezafuentes) (6)
#
# cornershop:perf/order_shopper_status_partial_idx https://github.com/cornershop/cornershop-backend/pull/19333 (mudetz) (6)
#
# cornershop:feat/ch61825/we-need-to-complete-the-inventory-step-when https://github.com/cornershop/cornershop-backend/pull/19346 (tomasdiaztoro) (4)
#
# cornershop:chore/ch53000/standardize-the-number-of-orders-displayed https://github.com/cornershop/cornershop-backend/pull/19327 (FernandoCandia) (4)
#
# cornershop:feat/uber/call-complete-for-unfinished-captures https://github.com/cornershop/cornershop-backend/pull/19320 (efredz) (4)
#
# cornershop:perf/promotions_monitor_without_order_join https://github.com/cornershop/cornershop-backend/pull/19305 (joekohlsdorf) (4)
#
# cornershop:feature/ch61098/refactor-a-retryable-task-in-shoppers-create https://github.com/cornershop/cornershop-backend/pull/19218 (user0able) (4)
#
# cornershop:bug/payments/amount-fix-release https://github.com/cornershop/cornershop-backend/pull/19371 (LuisSanchez) (3)
#
# cornershop:revert-19359-feature/ch61941/manage-httperror-in-load-unload-card https://github.com/cornershop/cornershop-backend/pull/19362 (user0able) (3)
#
# cornershop:feat/persist-uber-subscription-type https://github.com/cornershop/cornershop-backend/pull/19299 (efredz) (3)
#
# cornershop:feat/add-subscription-type-to-uber-subscription https://github.com/cornershop/cornershop-backend/pull/19274 (efredz) (3)
#
# cornershop:feature/ch61743/limit-access-to-view-booklogs-details-in https://github.com/cornershop/cornershop-backend/pull/19358 (FernandoCandia) (2)
#
# cornershop:chore/payments/ch60931/improve-card-assignation-error-messages-handling-migrate https://github.com/cornershop/cornershop-backend/pull/19357 (felipewove) (2)
#
# cornershop:chore/multipicking/exclude_spid35_from_mp_bot https://github.com/cornershop/cornershop-backend/pull/19351 (argenisfd) (2)
#
# cornershop:chore/users/update_registered_via_user_property https://github.com/cornershop/cornershop-backend/pull/19326 (nixaraven) (2)
#
# cornershop:asap_orders_confirmation https://github.com/cornershop/cornershop-backend/pull/19318 (caschiaffino) (2)
#
# cornershop:chore/add-new-events-to-uber-events https://github.com/cornershop/cornershop-backend/pull/19300 (efredz) (2)

# %%
prs
# Out:
# [{'number': 15539,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/15539',
#   'commits': 360,
#   'additions': 10095,
#   'deletions': 30,
#   'changed_files': 97,
#   'merged_at': datetime.datetime(2021, 1, 8, 12, 20, 58),
#   'created_at': datetime.datetime(2020, 10, 16, 16, 38, 54),
#   'updated_at': datetime.datetime(2021, 1, 8, 12, 20, 59),
#   'user': 'saherp145',
#   'score': 457},
#  {'number': 16720,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/16720',
#   'commits': 116,
#   'additions': 4350,
#   'deletions': 1081,
#   'changed_files': 101,
#   'merged_at': datetime.datetime(2021, 1, 6, 12, 34, 45),
#   'created_at': datetime.datetime(2020, 11, 19, 21, 0, 59),
#   'updated_at': datetime.datetime(2021, 1, 6, 12, 34, 46),
#   'user': 'bixtope',
#   'score': 217},
#  {'number': 18041,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18041',
#   'commits': 34,
#   'additions': 1509,
#   'deletions': 238,
#   'changed_files': 65,
#   'merged_at': datetime.datetime(2021, 1, 5, 12, 52, 39),
#   'created_at': datetime.datetime(2020, 12, 28, 13, 24, 12),
#   'updated_at': datetime.datetime(2021, 1, 5, 12, 52, 40),
#   'user': 'bixtope',
#   'score': 99},
#  {'number': 18042,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18042',
#   'commits': 30,
#   'additions': 1338,
#   'deletions': 101,
#   'changed_files': 24,
#   'merged_at': datetime.datetime(2021, 1, 5, 12, 52, 18),
#   'created_at': datetime.datetime(2020, 12, 28, 13, 33, 24),
#   'updated_at': datetime.datetime(2021, 1, 5, 12, 52, 19),
#   'user': 'bixtope',
#   'score': 54},
#  {'number': 17410,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17410',
#   'commits': 21,
#   'additions': 757,
#   'deletions': 177,
#   'changed_files': 31,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 37, 25),
#   'created_at': datetime.datetime(2020, 12, 9, 12, 40, 59),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 46, 33),
#   'user': 'felipesuazo',
#   'score': 52},
#  {'number': 18369,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18369',
#   'commits': 17,
#   'additions': 226,
#   'deletions': 457,
#   'changed_files': 29,
#   'merged_at': datetime.datetime(2021, 1, 8, 18, 34, 49),
#   'created_at': datetime.datetime(2021, 1, 7, 16, 9, 1),
#   'updated_at': datetime.datetime(2021, 1, 8, 18, 34, 51),
#   'user': 'royarzun',
#   'score': 46},
#  {'number': 18216,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18216',
#   'commits': 31,
#   'additions': 225,
#   'deletions': 27,
#   'changed_files': 14,
#   'merged_at': datetime.datetime(2021, 1, 5, 20, 18, 17),
#   'created_at': datetime.datetime(2021, 1, 4, 13, 39, 55),
#   'updated_at': datetime.datetime(2021, 1, 5, 20, 28, 13),
#   'user': 'lalfaro1704',
#   'score': 45},
#  {'number': 18010,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18010',
#   'commits': 23,
#   'additions': 978,
#   'deletions': 51,
#   'changed_files': 17,
#   'merged_at': datetime.datetime(2021, 1, 8, 20, 53, 21),
#   'created_at': datetime.datetime(2020, 12, 24, 13, 27, 35),
#   'updated_at': datetime.datetime(2021, 1, 8, 20, 53, 22),
#   'user': 'LuisSanchez',
#   'score': 40},
#  {'number': 18145,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18145',
#   'commits': 19,
#   'additions': 863,
#   'deletions': 94,
#   'changed_files': 18,
#   'merged_at': datetime.datetime(2021, 1, 6, 20, 42, 13),
#   'created_at': datetime.datetime(2020, 12, 30, 14, 38, 30),
#   'updated_at': datetime.datetime(2021, 1, 6, 20, 42, 15),
#   'user': 'abelfernandezh',
#   'score': 37},
#  {'number': 18196,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18196',
#   'commits': 24,
#   'additions': 231,
#   'deletions': 9,
#   'changed_files': 12,
#   'merged_at': datetime.datetime(2021, 1, 8, 12, 39, 41),
#   'created_at': datetime.datetime(2020, 12, 31, 17, 7, 6),
#   'updated_at': datetime.datetime(2021, 1, 8, 12, 39, 42),
#   'user': 'mopitz199',
#   'score': 36},
#  {'number': 18151,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18151',
#   'commits': 11,
#   'additions': 563,
#   'deletions': 21,
#   'changed_files': 18,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 47, 48),
#   'created_at': datetime.datetime(2020, 12, 30, 15, 30, 45),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 47, 49),
#   'user': 'felipesuazo',
#   'score': 29},
#  {'number': 18001,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18001',
#   'commits': 13,
#   'additions': 159,
#   'deletions': 5,
#   'changed_files': 15,
#   'merged_at': datetime.datetime(2021, 1, 5, 14, 17, 28),
#   'created_at': datetime.datetime(2020, 12, 24, 2, 2, 52),
#   'updated_at': datetime.datetime(2021, 1, 5, 14, 17, 29),
#   'user': 'lalfaro1704',
#   'score': 28},
#  {'number': 17990,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17990',
#   'commits': 17,
#   'additions': 483,
#   'deletions': 2,
#   'changed_files': 11,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 50, 21),
#   'created_at': datetime.datetime(2020, 12, 23, 19, 35, 11),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 50, 22),
#   'user': 'esteban03',
#   'score': 28},
#  {'number': 18293,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18293',
#   'commits': 14,
#   'additions': 337,
#   'deletions': 151,
#   'changed_files': 13,
#   'merged_at': datetime.datetime(2021, 1, 5, 21, 33, 51),
#   'created_at': datetime.datetime(2021, 1, 5, 20, 8, 26),
#   'updated_at': datetime.datetime(2021, 1, 5, 21, 44, 32),
#   'user': 'Goferk',
#   'score': 27},
#  {'number': 18086,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18086',
#   'commits': 18,
#   'additions': 477,
#   'deletions': 10,
#   'changed_files': 9,
#   'merged_at': datetime.datetime(2021, 1, 8, 15, 40, 40),
#   'created_at': datetime.datetime(2020, 12, 28, 22, 58, 34),
#   'updated_at': datetime.datetime(2021, 1, 8, 15, 40, 41),
#   'user': 'jwllee',
#   'score': 27},
#  {'number': 18126,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18126',
#   'commits': 15,
#   'additions': 477,
#   'deletions': 31,
#   'changed_files': 11,
#   'merged_at': datetime.datetime(2021, 1, 8, 18, 23, 26),
#   'created_at': datetime.datetime(2020, 12, 29, 20, 44, 52),
#   'updated_at': datetime.datetime(2021, 1, 8, 18, 23, 28),
#   'user': 'jwllee',
#   'score': 26},
#  {'number': 18135,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18135',
#   'commits': 12,
#   'additions': 1519,
#   'deletions': 1,
#   'changed_files': 13,
#   'merged_at': datetime.datetime(2021, 1, 4, 15, 20, 12),
#   'created_at': datetime.datetime(2020, 12, 29, 22, 38, 16),
#   'updated_at': datetime.datetime(2021, 1, 4, 15, 20, 13),
#   'user': 'julienbel',
#   'score': 25},
#  {'number': 18218,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18218',
#   'commits': 6,
#   'additions': 1055,
#   'deletions': 761,
#   'changed_files': 18,
#   'merged_at': datetime.datetime(2021, 1, 7, 18, 29, 55),
#   'created_at': datetime.datetime(2021, 1, 4, 13, 52, 12),
#   'updated_at': datetime.datetime(2021, 1, 7, 18, 29, 57),
#   'user': 'thwmax',
#   'score': 24},
#  {'number': 18331,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18331',
#   'commits': 8,
#   'additions': 368,
#   'deletions': 84,
#   'changed_files': 15,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 21, 5),
#   'created_at': datetime.datetime(2021, 1, 6, 19, 35, 56),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 21, 6),
#   'user': 'ngjonnathan',
#   'score': 23},
#  {'number': 18252,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18252',
#   'commits': 10,
#   'additions': 510,
#   'deletions': 169,
#   'changed_files': 13,
#   'merged_at': datetime.datetime(2021, 1, 6, 14, 32, 23),
#   'created_at': datetime.datetime(2021, 1, 4, 22, 1, 13),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 32, 24),
#   'user': 'axeliodiaz',
#   'score': 23},
#  {'number': 18422,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18422',
#   'commits': 11,
#   'additions': 176,
#   'deletions': 78,
#   'changed_files': 10,
#   'merged_at': datetime.datetime(2021, 1, 8, 15, 46, 10),
#   'created_at': datetime.datetime(2021, 1, 8, 15, 4, 43),
#   'updated_at': datetime.datetime(2021, 1, 8, 15, 46, 12),
#   'user': 'Goferk',
#   'score': 21},
#  {'number': 18155,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18155',
#   'commits': 13,
#   'additions': 156,
#   'deletions': 11,
#   'changed_files': 8,
#   'merged_at': datetime.datetime(2021, 1, 4, 19, 58, 39),
#   'created_at': datetime.datetime(2020, 12, 30, 17, 31, 38),
#   'updated_at': datetime.datetime(2021, 1, 4, 19, 58, 40),
#   'user': 'jicortes2',
#   'score': 21},
#  {'number': 18029,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18029',
#   'commits': 15,
#   'additions': 379,
#   'deletions': 3,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 49, 37),
#   'created_at': datetime.datetime(2020, 12, 24, 18, 51, 53),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 49, 38),
#   'user': 'jwllee',
#   'score': 21},
#  {'number': 17887,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17887',
#   'commits': 14,
#   'additions': 313,
#   'deletions': 3,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 6, 12, 17, 16),
#   'created_at': datetime.datetime(2020, 12, 21, 22, 16, 17),
#   'updated_at': datetime.datetime(2021, 1, 6, 12, 17, 17),
#   'user': 'andreariveros',
#   'score': 20},
#  {'number': 18352,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18352',
#   'commits': 8,
#   'additions': 33,
#   'deletions': 451,
#   'changed_files': 10,
#   'merged_at': datetime.datetime(2021, 1, 7, 14, 18, 38),
#   'created_at': datetime.datetime(2021, 1, 7, 13, 41, 9),
#   'updated_at': datetime.datetime(2021, 1, 7, 14, 20, 15),
#   'user': 'Goferk',
#   'score': 18},
#  {'number': 18292,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18292',
#   'commits': 4,
#   'additions': 82,
#   'deletions': 48,
#   'changed_files': 14,
#   'merged_at': datetime.datetime(2021, 1, 6, 14, 45, 5),
#   'created_at': datetime.datetime(2021, 1, 5, 19, 54, 9),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 45, 6),
#   'user': 'javierdihu',
#   'score': 18},
#  {'number': 18217,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18217',
#   'commits': 1,
#   'additions': 127,
#   'deletions': 44,
#   'changed_files': 17,
#   'merged_at': datetime.datetime(2021, 1, 7, 18, 51, 17),
#   'created_at': datetime.datetime(2021, 1, 4, 13, 49, 16),
#   'updated_at': datetime.datetime(2021, 1, 7, 18, 51, 18),
#   'user': 'ekauffmann',
#   'score': 18},
#  {'number': 18197,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18197',
#   'commits': 15,
#   'additions': 535,
#   'deletions': 150,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 14, 19, 57),
#   'created_at': datetime.datetime(2020, 12, 31, 17, 40, 23),
#   'updated_at': datetime.datetime(2021, 1, 5, 14, 19, 58),
#   'user': 'juanpablos',
#   'score': 18},
#  {'number': 18132,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18132',
#   'commits': 11,
#   'additions': 291,
#   'deletions': 47,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 4, 19, 16, 54),
#   'created_at': datetime.datetime(2020, 12, 29, 21, 51, 12),
#   'updated_at': datetime.datetime(2021, 1, 4, 19, 16, 55),
#   'user': 'jicortes2',
#   'score': 18},
#  {'number': 17999,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17999',
#   'commits': 3,
#   'additions': 23,
#   'deletions': 23,
#   'changed_files': 15,
#   'merged_at': datetime.datetime(2021, 1, 5, 13, 12, 40),
#   'created_at': datetime.datetime(2020, 12, 23, 23, 14, 43),
#   'updated_at': datetime.datetime(2021, 1, 5, 13, 12, 41),
#   'user': 'gabriel-arriagada',
#   'score': 18},
#  {'number': 18456,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18456',
#   'commits': 8,
#   'additions': 314,
#   'deletions': 17,
#   'changed_files': 9,
#   'merged_at': datetime.datetime(2021, 1, 9, 15, 37, 23),
#   'created_at': datetime.datetime(2021, 1, 9, 14, 24, 16),
#   'updated_at': datetime.datetime(2021, 1, 9, 15, 37, 24),
#   'user': 'javierdihu',
#   'score': 17},
#  {'number': 18429,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18429',
#   'commits': 2,
#   'additions': 652,
#   'deletions': 75,
#   'changed_files': 15,
#   'merged_at': datetime.datetime(2021, 1, 8, 19, 2, 56),
#   'created_at': datetime.datetime(2021, 1, 8, 18, 21, 25),
#   'updated_at': datetime.datetime(2021, 1, 8, 19, 2, 58),
#   'user': 'richardbm',
#   'score': 17},
#  {'number': 18341,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18341',
#   'commits': 8,
#   'additions': 159,
#   'deletions': 4,
#   'changed_files': 9,
#   'merged_at': datetime.datetime(2021, 1, 7, 17, 43),
#   'created_at': datetime.datetime(2021, 1, 6, 22, 20, 12),
#   'updated_at': datetime.datetime(2021, 1, 7, 17, 43, 2),
#   'user': 'knarf20',
#   'score': 17},
#  {'number': 18414,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18414',
#   'commits': 5,
#   'additions': 331,
#   'deletions': 244,
#   'changed_files': 11,
#   'merged_at': datetime.datetime(2021, 1, 9, 1, 9, 25),
#   'created_at': datetime.datetime(2021, 1, 8, 13, 50, 49),
#   'updated_at': datetime.datetime(2021, 1, 9, 1, 9, 26),
#   'user': 'felipesuazo',
#   'score': 16},
#  {'number': 18454,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18454',
#   'commits': 1,
#   'additions': 125,
#   'deletions': 37,
#   'changed_files': 14,
#   'merged_at': datetime.datetime(2021, 1, 9, 1, 29, 41),
#   'created_at': datetime.datetime(2021, 1, 9, 0, 59, 17),
#   'updated_at': datetime.datetime(2021, 1, 9, 1, 37, 45),
#   'user': 'richardbm',
#   'score': 15},
#  {'number': 18457,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18457',
#   'commits': 1,
#   'additions': 13,
#   'deletions': 13,
#   'changed_files': 13,
#   'merged_at': datetime.datetime(2021, 1, 9, 17, 23, 50),
#   'created_at': datetime.datetime(2021, 1, 9, 16, 53, 34),
#   'updated_at': datetime.datetime(2021, 1, 9, 17, 23, 51),
#   'user': 'crogel23',
#   'score': 14},
#  {'number': 18408,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18408',
#   'commits': 8,
#   'additions': 230,
#   'deletions': 9,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 8, 17, 0, 25),
#   'created_at': datetime.datetime(2021, 1, 8, 12, 24, 47),
#   'updated_at': datetime.datetime(2021, 1, 8, 17, 0, 26),
#   'user': 'pgarcia14180',
#   'score': 13},
#  {'number': 18403,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18403',
#   'commits': 7,
#   'additions': 80,
#   'deletions': 19,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 14, 59),
#   'created_at': datetime.datetime(2021, 1, 8, 2, 37, 30),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 15),
#   'user': 'javierdihu',
#   'score': 13},
#  {'number': 18326,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18326',
#   'commits': 7,
#   'additions': 95,
#   'deletions': 5,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 16, 47, 41),
#   'created_at': datetime.datetime(2021, 1, 6, 18, 26, 23),
#   'updated_at': datetime.datetime(2021, 1, 8, 16, 47, 43),
#   'user': 'KanzakiRanko1',
#   'score': 13},
#  {'number': 17924,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17924',
#   'commits': 5,
#   'additions': 284,
#   'deletions': 70,
#   'changed_files': 8,
#   'merged_at': datetime.datetime(2021, 1, 6, 21, 55, 49),
#   'created_at': datetime.datetime(2020, 12, 22, 18, 45, 53),
#   'updated_at': datetime.datetime(2021, 1, 6, 21, 55, 51),
#   'user': 'jwllee',
#   'score': 13},
#  {'number': 18271,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18271',
#   'commits': 4,
#   'additions': 235,
#   'deletions': 159,
#   'changed_files': 8,
#   'merged_at': datetime.datetime(2021, 1, 5, 21, 28, 42),
#   'created_at': datetime.datetime(2021, 1, 5, 15, 24, 46),
#   'updated_at': datetime.datetime(2021, 1, 5, 21, 28, 43),
#   'user': 'pmirandaa',
#   'score': 12},
#  {'number': 18347,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18347',
#   'commits': 5,
#   'additions': 36,
#   'deletions': 7,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 14, 42, 17),
#   'created_at': datetime.datetime(2021, 1, 7, 1, 46, 11),
#   'updated_at': datetime.datetime(2021, 1, 8, 14, 42, 18),
#   'user': 'ignacioHermosilla',
#   'score': 11},
#  {'number': 18213,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18213',
#   'commits': 7,
#   'additions': 263,
#   'deletions': 245,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 6, 12, 13, 26),
#   'created_at': datetime.datetime(2021, 1, 4, 12, 14, 42),
#   'updated_at': datetime.datetime(2021, 1, 6, 12, 13, 27),
#   'user': 'julienbel',
#   'score': 11},
#  {'number': 18169,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18169',
#   'commits': 8,
#   'additions': 71,
#   'deletions': 7,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 4, 12, 17, 42),
#   'created_at': datetime.datetime(2020, 12, 30, 21, 41, 39),
#   'updated_at': datetime.datetime(2021, 1, 4, 12, 17, 43),
#   'user': 'saherp145',
#   'score': 11},
#  {'number': 18033,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18033',
#   'commits': 6,
#   'additions': 419,
#   'deletions': 1,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 7, 16, 42, 49),
#   'created_at': datetime.datetime(2020, 12, 27, 17, 50, 50),
#   'updated_at': datetime.datetime(2021, 1, 7, 16, 42, 51),
#   'user': 'jwllee',
#   'score': 11},
#  {'number': 17977,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17977',
#   'commits': 5,
#   'additions': 365,
#   'deletions': 8,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 5, 14, 58, 4),
#   'created_at': datetime.datetime(2020, 12, 23, 18, 8, 26),
#   'updated_at': datetime.datetime(2021, 1, 5, 14, 58, 5),
#   'user': 'orutrax',
#   'score': 11},
#  {'number': 16031,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/16031',
#   'commits': 4,
#   'additions': 99,
#   'deletions': 61,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 6, 14, 30),
#   'created_at': datetime.datetime(2020, 10, 30, 21, 32, 47),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 30, 1),
#   'user': 'CrisOA',
#   'score': 11},
#  {'number': 18361,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18361',
#   'commits': 5,
#   'additions': 22,
#   'deletions': 6,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 7, 18, 27, 47),
#   'created_at': datetime.datetime(2021, 1, 7, 15, 2, 50),
#   'updated_at': datetime.datetime(2021, 1, 7, 18, 27, 49),
#   'user': 'javierdihu',
#   'score': 10},
#  {'number': 18328,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18328',
#   'commits': 2,
#   'additions': 121,
#   'deletions': 22,
#   'changed_files': 8,
#   'merged_at': datetime.datetime(2021, 1, 6, 20, 1, 48),
#   'created_at': datetime.datetime(2021, 1, 6, 18, 27, 15),
#   'updated_at': datetime.datetime(2021, 1, 6, 20, 1, 49),
#   'user': 'axeliodiaz',
#   'score': 10},
#  {'number': 18303,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18303',
#   'commits': 3,
#   'additions': 144,
#   'deletions': 3,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 6, 13, 33, 31),
#   'created_at': datetime.datetime(2021, 1, 5, 21, 27, 2),
#   'updated_at': datetime.datetime(2021, 1, 6, 13, 33, 32),
#   'user': 'jwllee',
#   'score': 10},
#  {'number': 18294,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18294',
#   'commits': 4,
#   'additions': 449,
#   'deletions': 90,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 6, 19, 7, 40),
#   'created_at': datetime.datetime(2021, 1, 5, 20, 9, 57),
#   'updated_at': datetime.datetime(2021, 1, 6, 19, 7, 41),
#   'user': 'thwmax',
#   'score': 10},
#  {'number': 18282,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18282',
#   'commits': 6,
#   'additions': 89,
#   'deletions': 17,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 8, 17),
#   'created_at': datetime.datetime(2021, 1, 5, 17, 38, 58),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 8, 19),
#   'user': 'rriquelm',
#   'score': 10},
#  {'number': 18387,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18387',
#   'commits': 7,
#   'additions': 35,
#   'deletions': 6,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 8, 17, 50, 26),
#   'created_at': datetime.datetime(2021, 1, 7, 19, 47, 20),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 36, 33),
#   'user': 'Nach1n',
#   'score': 9},
#  {'number': 18342,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18342',
#   'commits': 6,
#   'additions': 27,
#   'deletions': 13,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 7, 42),
#   'created_at': datetime.datetime(2021, 1, 6, 22, 25, 54),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 7, 43),
#   'user': 'bixtope',
#   'score': 9},
#  {'number': 18335,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18335',
#   'commits': 1,
#   'additions': 38,
#   'deletions': 32,
#   'changed_files': 8,
#   'merged_at': datetime.datetime(2021, 1, 7, 14, 15, 51),
#   'created_at': datetime.datetime(2021, 1, 6, 20, 28, 11),
#   'updated_at': datetime.datetime(2021, 1, 7, 14, 15, 52),
#   'user': 'mudetz',
#   'score': 9},
#  {'number': 18281,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18281',
#   'commits': 6,
#   'additions': 88,
#   'deletions': 83,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 20, 11, 55),
#   'created_at': datetime.datetime(2021, 1, 5, 17, 22, 59),
#   'updated_at': datetime.datetime(2021, 1, 5, 20, 12),
#   'user': 'conilastra',
#   'score': 9},
#  {'number': 18245,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18245',
#   'commits': 3,
#   'additions': 186,
#   'deletions': 8,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 13, 52),
#   'created_at': datetime.datetime(2021, 1, 4, 20, 28, 30),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 13, 53),
#   'user': 'jbasualdo',
#   'score': 9},
#  {'number': 18211,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18211',
#   'commits': 3,
#   'additions': 96,
#   'deletions': 6,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 4, 19, 59, 6),
#   'created_at': datetime.datetime(2021, 1, 3, 19, 17, 21),
#   'updated_at': datetime.datetime(2021, 1, 4, 19, 59, 7),
#   'user': 'jbasualdo',
#   'score': 9},
#  {'number': 18446,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18446',
#   'commits': 3,
#   'additions': 94,
#   'deletions': 31,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 54, 28),
#   'created_at': datetime.datetime(2021, 1, 8, 21, 25, 4),
#   'updated_at': datetime.datetime(2021, 1, 8, 22, 3, 32),
#   'user': 'ngjonnathan',
#   'score': 8},
#  {'number': 18445,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18445',
#   'commits': 2,
#   'additions': 228,
#   'deletions': 361,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 25, 59),
#   'created_at': datetime.datetime(2021, 1, 8, 21, 11, 54),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 26),
#   'user': 'ignacioHermosilla',
#   'score': 8},
#  {'number': 18433,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18433',
#   'commits': 2,
#   'additions': 227,
#   'deletions': 400,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 19, 38, 32),
#   'created_at': datetime.datetime(2021, 1, 8, 19, 17, 46),
#   'updated_at': datetime.datetime(2021, 1, 8, 19, 50, 2),
#   'user': 'ignacioHermosilla',
#   'score': 8},
#  {'number': 18346,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18346',
#   'commits': 5,
#   'additions': 77,
#   'deletions': 16,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 7, 22, 55, 24),
#   'created_at': datetime.datetime(2021, 1, 6, 23, 53, 49),
#   'updated_at': datetime.datetime(2021, 1, 7, 22, 55, 25),
#   'user': 'pgarcia14180',
#   'score': 8},
#  {'number': 18298,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18298',
#   'commits': 1,
#   'additions': 86,
#   'deletions': 62,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 7, 18, 37, 5),
#   'created_at': datetime.datetime(2021, 1, 5, 20, 38, 26),
#   'updated_at': datetime.datetime(2021, 1, 7, 18, 37, 7),
#   'user': 'sergs2003',
#   'score': 8},
#  {'number': 18287,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18287',
#   'commits': 4,
#   'additions': 84,
#   'deletions': 1,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 6, 12, 58, 23),
#   'created_at': datetime.datetime(2021, 1, 5, 18, 45, 8),
#   'updated_at': datetime.datetime(2021, 1, 6, 12, 58, 25),
#   'user': 'esteban03',
#   'score': 8},
#  {'number': 18258,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18258',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 358,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 5, 13, 38, 48),
#   'created_at': datetime.datetime(2021, 1, 5, 12, 46, 19),
#   'updated_at': datetime.datetime(2021, 1, 5, 13, 39, 56),
#   'user': 'jicortes2',
#   'score': 8},
#  {'number': 18256,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18256',
#   'commits': 7,
#   'additions': 18,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 42, 6),
#   'created_at': datetime.datetime(2021, 1, 5, 1, 50, 9),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 42, 7),
#   'user': 'lalfaro1704',
#   'score': 8},
#  {'number': 17938,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17938',
#   'commits': 1,
#   'additions': 73,
#   'deletions': 19,
#   'changed_files': 7,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 31, 8),
#   'created_at': datetime.datetime(2020, 12, 22, 21, 31, 32),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 31, 9),
#   'user': 'rriquelm',
#   'score': 8},
#  {'number': 17922,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17922',
#   'commits': 4,
#   'additions': 99,
#   'deletions': 1,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 7, 17, 13, 28),
#   'created_at': datetime.datetime(2020, 12, 22, 18, 15, 15),
#   'updated_at': datetime.datetime(2021, 1, 7, 17, 13, 29),
#   'user': 'CrisOA',
#   'score': 8},
#  {'number': 17650,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17650',
#   'commits': 6,
#   'additions': 71,
#   'deletions': 1,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 4, 13, 13, 54),
#   'created_at': datetime.datetime(2020, 12, 15, 16, 53, 41),
#   'updated_at': datetime.datetime(2021, 1, 4, 13, 13, 56),
#   'user': 'pfariaz',
#   'score': 8},
#  {'number': 18424,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18424',
#   'commits': 5,
#   'additions': 135,
#   'deletions': 85,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 13, 43),
#   'created_at': datetime.datetime(2021, 1, 8, 15, 37, 24),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 13, 44),
#   'user': 'javierdihu',
#   'score': 7},
#  {'number': 18374,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18374',
#   'commits': 1,
#   'additions': 68,
#   'deletions': 63,
#   'changed_files': 6,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 26, 59),
#   'created_at': datetime.datetime(2021, 1, 7, 17, 49, 3),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 27),
#   'user': 'sergs2003',
#   'score': 7},
#  {'number': 18267,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18267',
#   'commits': 3,
#   'additions': 3,
#   'deletions': 53,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 53, 16),
#   'created_at': datetime.datetime(2021, 1, 5, 15, 3, 6),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 53, 17),
#   'user': 'bixtope',
#   'score': 7},
#  {'number': 18242,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18242',
#   'commits': 2,
#   'additions': 94,
#   'deletions': 6,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 6, 15, 25, 54),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 53, 37),
#   'updated_at': datetime.datetime(2021, 1, 6, 15, 25, 55),
#   'user': 'jbasualdo',
#   'score': 7},
#  {'number': 18219,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18219',
#   'commits': 2,
#   'additions': 13,
#   'deletions': 3,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 4, 15, 45, 28),
#   'created_at': datetime.datetime(2021, 1, 4, 14, 12, 30),
#   'updated_at': datetime.datetime(2021, 1, 4, 15, 45, 30),
#   'user': 'roalonso',
#   'score': 7},
#  {'number': 18417,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18417',
#   'commits': 2,
#   'additions': 74,
#   'deletions': 4,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 55, 31),
#   'created_at': datetime.datetime(2021, 1, 8, 14, 14, 19),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 55, 32),
#   'user': 'julienbel',
#   'score': 6},
#  {'number': 18409,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18409',
#   'commits': 2,
#   'additions': 14,
#   'deletions': 6,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 14, 4, 55),
#   'created_at': datetime.datetime(2021, 1, 8, 12, 51, 40),
#   'updated_at': datetime.datetime(2021, 1, 8, 14, 4, 56),
#   'user': 'gruizmir',
#   'score': 6},
#  {'number': 18261,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18261',
#   'commits': 1,
#   'additions': 16,
#   'deletions': 10,
#   'changed_files': 5,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 7, 56),
#   'created_at': datetime.datetime(2021, 1, 5, 14, 4, 55),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 7, 57),
#   'user': 'CrisOA',
#   'score': 6},
#  {'number': 18240,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18240',
#   'commits': 3,
#   'additions': 29,
#   'deletions': 1,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 14, 31, 9),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 40, 24),
#   'updated_at': datetime.datetime(2021, 1, 5, 14, 31, 10),
#   'user': 'argenisfd',
#   'score': 6},
#  {'number': 18431,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18431',
#   'commits': 1,
#   'additions': 37,
#   'deletions': 28,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 19, 50, 23),
#   'created_at': datetime.datetime(2021, 1, 8, 19, 3, 16),
#   'updated_at': datetime.datetime(2021, 1, 8, 19, 50, 24),
#   'user': 'royarzun',
#   'score': 5},
#  {'number': 18388,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18388',
#   'commits': 1,
#   'additions': 13,
#   'deletions': 9,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 9, 26),
#   'created_at': datetime.datetime(2021, 1, 7, 19, 47, 57),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 9, 28),
#   'user': 'alexaxms',
#   'score': 5},
#  {'number': 18385,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18385',
#   'commits': 2,
#   'additions': 23,
#   'deletions': 2,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 8, 16, 3, 6),
#   'created_at': datetime.datetime(2021, 1, 7, 19, 30, 15),
#   'updated_at': datetime.datetime(2021, 1, 8, 16, 3, 7),
#   'user': 'tomasdiaztoro',
#   'score': 5},
#  {'number': 18363,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18363',
#   'commits': 1,
#   'additions': 19,
#   'deletions': 13,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 47, 59),
#   'created_at': datetime.datetime(2021, 1, 7, 15, 9, 25),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 48),
#   'user': 'esteban03',
#   'score': 5},
#  {'number': 18350,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18350',
#   'commits': 1,
#   'additions': 48,
#   'deletions': 21,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 58, 54),
#   'created_at': datetime.datetime(2021, 1, 7, 13, 20, 46),
#   'updated_at': datetime.datetime(2021, 1, 7, 16, 8, 42),
#   'user': 'ekauffmann',
#   'score': 5},
#  {'number': 18337,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18337',
#   'commits': 3,
#   'additions': 43,
#   'deletions': 3,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 5, 7),
#   'created_at': datetime.datetime(2021, 1, 6, 21, 14, 32),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 5, 8),
#   'user': 'orutrax',
#   'score': 5},
#  {'number': 18327,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18327',
#   'commits': 2,
#   'additions': 69,
#   'deletions': 10,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 6, 21, 53, 49),
#   'created_at': datetime.datetime(2021, 1, 6, 18, 26, 46),
#   'updated_at': datetime.datetime(2021, 1, 6, 22, 2, 6),
#   'user': 'argenisfd',
#   'score': 5},
#  {'number': 18325,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18325',
#   'commits': 2,
#   'additions': 5,
#   'deletions': 4,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 6, 21, 0, 31),
#   'created_at': datetime.datetime(2021, 1, 6, 18, 8, 15),
#   'updated_at': datetime.datetime(2021, 1, 6, 21, 0, 32),
#   'user': 'crogel23',
#   'score': 5},
#  {'number': 18320,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18320',
#   'commits': 3,
#   'additions': 3,
#   'deletions': 3,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 17, 39, 48),
#   'created_at': datetime.datetime(2021, 1, 6, 15, 36, 55),
#   'updated_at': datetime.datetime(2021, 1, 6, 17, 39, 49),
#   'user': 'esteban03',
#   'score': 5},
#  {'number': 18311,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18311',
#   'commits': 3,
#   'additions': 63,
#   'deletions': 6,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 18, 12, 46),
#   'created_at': datetime.datetime(2021, 1, 6, 13, 29, 9),
#   'updated_at': datetime.datetime(2021, 1, 6, 18, 12, 47),
#   'user': 'orutrax',
#   'score': 5},
#  {'number': 18302,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18302',
#   'commits': 2,
#   'additions': 508,
#   'deletions': 0,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 6, 14, 40, 4),
#   'created_at': datetime.datetime(2021, 1, 5, 21, 18, 55),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 40, 6),
#   'user': 'Nach1n',
#   'score': 5},
#  {'number': 18235,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18235',
#   'commits': 4,
#   'additions': 2,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 19, 7, 50),
#   'created_at': datetime.datetime(2021, 1, 4, 18, 54, 13),
#   'updated_at': datetime.datetime(2021, 1, 6, 19, 7, 51),
#   'user': 'tmunoz',
#   'score': 5},
#  {'number': 18231,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18231',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 340,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 14, 3),
#   'created_at': datetime.datetime(2021, 1, 4, 17, 43, 38),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 14, 5),
#   'user': 'clinoge',
#   'score': 5},
#  {'number': 18214,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18214',
#   'commits': 2,
#   'additions': 19,
#   'deletions': 14,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 4, 14, 2, 58),
#   'created_at': datetime.datetime(2021, 1, 4, 12, 54, 56),
#   'updated_at': datetime.datetime(2021, 1, 4, 14, 2, 59),
#   'user': 'sergs2003',
#   'score': 5},
#  {'number': 18168,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18168',
#   'commits': 2,
#   'additions': 7,
#   'deletions': 8,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 12, 59),
#   'created_at': datetime.datetime(2020, 12, 30, 21, 17, 37),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 13),
#   'user': 'ianbortnic242',
#   'score': 5},
#  {'number': 18161,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18161',
#   'commits': 3,
#   'additions': 25,
#   'deletions': 1,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 4, 15, 26, 39),
#   'created_at': datetime.datetime(2020, 12, 30, 19, 10, 59),
#   'updated_at': datetime.datetime(2021, 1, 4, 15, 26, 40),
#   'user': 'jicortes2',
#   'score': 5},
#  {'number': 18160,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18160',
#   'commits': 2,
#   'additions': 53,
#   'deletions': 4,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 4, 16, 54, 18),
#   'created_at': datetime.datetime(2020, 12, 30, 19, 3, 54),
#   'updated_at': datetime.datetime(2021, 1, 4, 16, 54, 19),
#   'user': 'jbasualdo',
#   'score': 5},
#  {'number': 17339,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17339',
#   'commits': 1,
#   'additions': 116,
#   'deletions': 0,
#   'changed_files': 4,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 36, 42),
#   'created_at': datetime.datetime(2020, 12, 4, 20, 34, 55),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 36, 43),
#   'user': 'efredz',
#   'score': 5},
#  {'number': 18451,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18451',
#   'commits': 1,
#   'additions': 3,
#   'deletions': 2,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 9, 14, 15, 4),
#   'created_at': datetime.datetime(2021, 1, 8, 22, 52, 26),
#   'updated_at': datetime.datetime(2021, 1, 9, 14, 15, 5),
#   'user': 'Nach1n',
#   'score': 4},
#  {'number': 18427,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18427',
#   'commits': 1,
#   'additions': 96,
#   'deletions': 17,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 8, 18, 58, 2),
#   'created_at': datetime.datetime(2021, 1, 8, 17, 16, 57),
#   'updated_at': datetime.datetime(2021, 1, 8, 18, 58, 3),
#   'user': 'MauricioAntunez',
#   'score': 4},
#  {'number': 18397,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18397',
#   'commits': 2,
#   'additions': 11,
#   'deletions': 1,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 8, 16, 9, 18),
#   'created_at': datetime.datetime(2021, 1, 7, 21, 59, 49),
#   'updated_at': datetime.datetime(2021, 1, 8, 16, 9, 19),
#   'user': 'diegopintog',
#   'score': 4},
#  {'number': 18370,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18370',
#   'commits': 2,
#   'additions': 6,
#   'deletions': 1,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 8, 12, 53, 29),
#   'created_at': datetime.datetime(2021, 1, 7, 16, 13, 4),
#   'updated_at': datetime.datetime(2021, 1, 8, 12, 53, 30),
#   'user': 'richardbm',
#   'score': 4},
#  {'number': 18359,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18359',
#   'commits': 1,
#   'additions': 67,
#   'deletions': 2,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 7, 16, 25, 6),
#   'created_at': datetime.datetime(2021, 1, 7, 14, 42, 19),
#   'updated_at': datetime.datetime(2021, 1, 7, 16, 30, 19),
#   'user': 'mudetz',
#   'score': 4},
#  {'number': 18323,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18323',
#   'commits': 2,
#   'additions': 44,
#   'deletions': 4,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 17, 23, 46),
#   'created_at': datetime.datetime(2021, 1, 6, 16, 41, 50),
#   'updated_at': datetime.datetime(2021, 1, 6, 17, 23, 47),
#   'user': 'Goferk',
#   'score': 4},
#  {'number': 18301,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18301',
#   'commits': 3,
#   'additions': 68,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 10, 59, 39),
#   'created_at': datetime.datetime(2021, 1, 5, 21, 3, 52),
#   'updated_at': datetime.datetime(2021, 1, 6, 10, 59, 40),
#   'user': 'argenisfd',
#   'score': 4},
#  {'number': 18300,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18300',
#   'commits': 2,
#   'additions': 8,
#   'deletions': 7,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 21, 51, 43),
#   'created_at': datetime.datetime(2021, 1, 5, 20, 52, 30),
#   'updated_at': datetime.datetime(2021, 1, 6, 21, 51, 44),
#   'user': 'lausan029',
#   'score': 4},
#  {'number': 18295,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18295',
#   'commits': 2,
#   'additions': 26,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 15, 25, 17),
#   'created_at': datetime.datetime(2021, 1, 5, 20, 10, 14),
#   'updated_at': datetime.datetime(2021, 1, 6, 15, 25, 18),
#   'user': 'lausan029',
#   'score': 4},
#  {'number': 18278,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18278',
#   'commits': 3,
#   'additions': 13,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 22, 3, 21),
#   'created_at': datetime.datetime(2021, 1, 5, 16, 29, 34),
#   'updated_at': datetime.datetime(2021, 1, 5, 22, 3, 23),
#   'user': 'saherp145',
#   'score': 4},
#  {'number': 18277,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18277',
#   'commits': 2,
#   'additions': 9,
#   'deletions': 34,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 5, 17, 23, 54),
#   'created_at': datetime.datetime(2021, 1, 5, 16, 21, 26),
#   'updated_at': datetime.datetime(2021, 1, 5, 17, 23, 55),
#   'user': 'juanpablos',
#   'score': 4},
#  {'number': 18263,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18263',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 8,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 19, 20, 19),
#   'created_at': datetime.datetime(2021, 1, 5, 14, 7, 38),
#   'updated_at': datetime.datetime(2021, 1, 5, 19, 20, 20),
#   'user': 'argenisfd',
#   'score': 4},
#  {'number': 18251,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18251',
#   'commits': 2,
#   'additions': 3,
#   'deletions': 1,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 4, 22, 24, 20),
#   'created_at': datetime.datetime(2021, 1, 4, 22, 0, 23),
#   'updated_at': datetime.datetime(2021, 1, 4, 22, 36, 8),
#   'user': 'gruizmir',
#   'score': 4},
#  {'number': 18239,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18239',
#   'commits': 2,
#   'additions': 33,
#   'deletions': 6,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 19, 34, 34),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 33, 26),
#   'updated_at': datetime.datetime(2021, 1, 6, 19, 34, 36),
#   'user': 'jbasualdo',
#   'score': 4},
#  {'number': 18237,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18237',
#   'commits': 2,
#   'additions': 10,
#   'deletions': 6,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 6, 17, 7, 43),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 24, 2),
#   'updated_at': datetime.datetime(2021, 1, 6, 17, 7, 44),
#   'user': 'jbasualdo',
#   'score': 4},
#  {'number': 18222,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18222',
#   'commits': 2,
#   'additions': 25,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 5, 4, 3, 28),
#   'created_at': datetime.datetime(2021, 1, 4, 15, 13, 26),
#   'updated_at': datetime.datetime(2021, 1, 5, 4, 3, 29),
#   'user': 'LuisSanchez',
#   'score': 4},
#  {'number': 18123,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18123',
#   'commits': 1,
#   'additions': 83,
#   'deletions': 4,
#   'changed_files': 3,
#   'merged_at': datetime.datetime(2021, 1, 5, 12, 35, 57),
#   'created_at': datetime.datetime(2020, 12, 29, 19, 56, 51),
#   'updated_at': datetime.datetime(2021, 1, 5, 12, 35, 58),
#   'user': 'ekauffmann',
#   'score': 4},
#  {'number': 18004,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18004',
#   'commits': 2,
#   'additions': 106,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 4, 13, 10, 26),
#   'created_at': datetime.datetime(2020, 12, 24, 3, 57, 56),
#   'updated_at': datetime.datetime(2021, 1, 4, 13, 10, 27),
#   'user': 'pfariaz',
#   'score': 4},
#  {'number': 17532,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17532',
#   'commits': 2,
#   'additions': 20,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 22, 57),
#   'created_at': datetime.datetime(2020, 12, 11, 14, 16, 1),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 22, 58),
#   'user': 'cothidalgo',
#   'score': 4},
#  {'number': 17361,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17361',
#   'commits': 3,
#   'additions': 6,
#   'deletions': 6,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 13, 19, 20),
#   'created_at': datetime.datetime(2020, 12, 5, 2, 48, 47),
#   'updated_at': datetime.datetime(2021, 1, 6, 13, 19, 21),
#   'user': 'joekohlsdorf',
#   'score': 4},
#  {'number': 18460,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18460',
#   'commits': 1,
#   'additions': 75,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 10, 13, 31, 8),
#   'created_at': datetime.datetime(2021, 1, 10, 12, 24, 38),
#   'updated_at': datetime.datetime(2021, 1, 10, 13, 31, 9),
#   'user': 'plreyes',
#   'score': 3},
#  {'number': 18459,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18459',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 11,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 10, 10, 0, 34),
#   'created_at': datetime.datetime(2021, 1, 9, 21, 46, 37),
#   'updated_at': datetime.datetime(2021, 1, 10, 10, 0, 35),
#   'user': 'plreyes',
#   'score': 3},
#  {'number': 18444,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18444',
#   'commits': 2,
#   'additions': 0,
#   'deletions': 7,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 38, 35),
#   'created_at': datetime.datetime(2021, 1, 8, 20, 54, 37),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 38, 36),
#   'user': 'pgarcia14180',
#   'score': 3},
#  {'number': 18438,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18438',
#   'commits': 2,
#   'additions': 6,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 8, 21, 36, 3),
#   'created_at': datetime.datetime(2021, 1, 8, 20, 12, 57),
#   'updated_at': datetime.datetime(2021, 1, 8, 21, 36, 4),
#   'user': 'Nach1n',
#   'score': 3},
#  {'number': 18394,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18394',
#   'commits': 1,
#   'additions': 41,
#   'deletions': 5,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 8, 12, 41, 11),
#   'created_at': datetime.datetime(2021, 1, 7, 21, 20, 43),
#   'updated_at': datetime.datetime(2021, 1, 8, 12, 41, 13),
#   'user': 'efredz',
#   'score': 3},
#  {'number': 18371,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18371',
#   'commits': 1,
#   'additions': 12,
#   'deletions': 4,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 7, 16, 56, 45),
#   'created_at': datetime.datetime(2021, 1, 7, 16, 13, 24),
#   'updated_at': datetime.datetime(2021, 1, 7, 16, 56, 47),
#   'user': 'ekauffmann',
#   'score': 3},
#  {'number': 18355,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18355',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 0,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 53, 32),
#   'created_at': datetime.datetime(2021, 1, 7, 14, 13),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 53, 33),
#   'user': 'thwmax',
#   'score': 3},
#  {'number': 18340,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18340',
#   'commits': 2,
#   'additions': 4,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 21, 52, 56),
#   'created_at': datetime.datetime(2021, 1, 6, 21, 33, 22),
#   'updated_at': datetime.datetime(2021, 1, 6, 21, 52, 57),
#   'user': 'bixtope',
#   'score': 3},
#  {'number': 18338,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18338',
#   'commits': 1,
#   'additions': 6,
#   'deletions': 3,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 14, 37),
#   'created_at': datetime.datetime(2021, 1, 6, 21, 20),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 14, 38),
#   'user': 'jbasualdo',
#   'score': 3},
#  {'number': 18336,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18336',
#   'commits': 1,
#   'additions': 15,
#   'deletions': 12,
#   'changed_files': 2,
#   'merged_at': datetime.datetime(2021, 1, 7, 0, 57, 21),
#   'created_at': datetime.datetime(2021, 1, 6, 20, 33, 52),
#   'updated_at': datetime.datetime(2021, 1, 7, 0, 57, 22),
#   'user': 'conilastra',
# ...
#   'updated_at': datetime.datetime(2021, 1, 8, 19, 41, 54),
#   'user': 'gruizmir',
#   'score': 2},
#  {'number': 18410,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18410',
#   'commits': 1,
#   'additions': 5,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 8, 13, 16, 50),
#   'created_at': datetime.datetime(2021, 1, 8, 13, 2, 19),
#   'updated_at': datetime.datetime(2021, 1, 8, 13, 16, 51),
#   'user': 'saherp145',
#   'score': 2},
#  {'number': 18389,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18389',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 18, 3),
#   'created_at': datetime.datetime(2021, 1, 7, 19, 50, 51),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 26, 5),
#   'user': 'tomasdiaztoro',
#   'score': 2},
#  {'number': 18386,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18386',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 22, 43),
#   'created_at': datetime.datetime(2021, 1, 7, 19, 34, 13),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 22, 45),
#   'user': 'fmiranda22',
#   'score': 2},
#  {'number': 18373,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18373',
#   'commits': 1,
#   'additions': 6,
#   'deletions': 6,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 17, 44, 15),
#   'created_at': datetime.datetime(2021, 1, 7, 17, 26, 6),
#   'updated_at': datetime.datetime(2021, 1, 7, 17, 44, 16),
#   'user': 'Nach1n',
#   'score': 2},
#  {'number': 18365,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18365',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 18, 19, 7),
#   'created_at': datetime.datetime(2021, 1, 7, 15, 37, 45),
#   'updated_at': datetime.datetime(2021, 1, 7, 18, 19, 8),
#   'user': 'MauricioAntunez',
#   'score': 2},
#  {'number': 18360,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18360',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 13, 23),
#   'created_at': datetime.datetime(2021, 1, 7, 14, 53, 48),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 13, 24),
#   'user': 'lalfaro1704',
#   'score': 2},
#  {'number': 18358,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18358',
#   'commits': 1,
#   'additions': 14,
#   'deletions': 14,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 10, 41),
#   'created_at': datetime.datetime(2021, 1, 7, 14, 40, 59),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 16, 15),
#   'user': 'Nach1n',
#   'score': 2},
#  {'number': 18356,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18356',
#   'commits': 1,
#   'additions': 8,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 20, 53, 41),
#   'created_at': datetime.datetime(2021, 1, 7, 14, 13, 13),
#   'updated_at': datetime.datetime(2021, 1, 7, 20, 53, 42),
#   'user': 'thwmax',
#   'score': 2},
#  {'number': 18351,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18351',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 8,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 52, 37),
#   'created_at': datetime.datetime(2021, 1, 7, 13, 21, 44),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 58, 13),
#   'user': 'bixtope',
#   'score': 2},
#  {'number': 18349,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18349',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 13, 4, 9),
#   'created_at': datetime.datetime(2021, 1, 7, 12, 23, 26),
#   'updated_at': datetime.datetime(2021, 1, 7, 13, 4, 10),
#   'user': 'Nach1n',
#   'score': 2},
#  {'number': 18343,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18343',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 3, 29),
#   'created_at': datetime.datetime(2021, 1, 6, 23, 27, 4),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 3, 31),
#   'user': 'diegopintog',
#   'score': 2},
#  {'number': 18339,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18339',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 16,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 22, 3),
#   'created_at': datetime.datetime(2021, 1, 6, 21, 26, 2),
#   'updated_at': datetime.datetime(2021, 1, 6, 22, 3, 1),
#   'user': 'juanpablos',
#   'score': 2},
#  {'number': 18324,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18324',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 18, 40, 36),
#   'created_at': datetime.datetime(2021, 1, 6, 17, 9, 13),
#   'updated_at': datetime.datetime(2021, 1, 6, 18, 40, 38),
#   'user': 'diegobano',
#   'score': 2},
#  {'number': 18322,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18322',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 17, 1, 20),
#   'created_at': datetime.datetime(2021, 1, 6, 16, 18, 34),
#   'updated_at': datetime.datetime(2021, 1, 6, 17, 1, 21),
#   'user': 'rriquelm',
#   'score': 2},
#  {'number': 18319,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18319',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 2,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 15, 34, 35),
#   'created_at': datetime.datetime(2021, 1, 6, 15, 19, 6),
#   'updated_at': datetime.datetime(2021, 1, 6, 15, 34, 37),
#   'user': 'ngjonnathan',
#   'score': 2},
#  {'number': 18318,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18318',
#   'commits': 1,
#   'additions': 7,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 15, 34, 1),
#   'created_at': datetime.datetime(2021, 1, 6, 15, 15, 59),
#   'updated_at': datetime.datetime(2021, 1, 6, 15, 34, 3),
#   'user': 'joacocruz6',
#   'score': 2},
#  {'number': 18314,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18314',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 33,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 15, 35, 58),
#   'created_at': datetime.datetime(2021, 1, 6, 14, 42, 42),
#   'updated_at': datetime.datetime(2021, 1, 6, 15, 35, 59),
#   'user': 'Goferk',
#   'score': 2},
#  {'number': 18310,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18310',
#   'commits': 1,
#   'additions': 5,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 14, 11, 33),
#   'created_at': datetime.datetime(2021, 1, 6, 13, 28, 17),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 11, 34),
#   'user': 'jicortes2',
#   'score': 2},
#  {'number': 18309,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18309',
#   'commits': 1,
#   'additions': 17,
#   'deletions': 18,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 13, 59, 1),
#   'created_at': datetime.datetime(2021, 1, 6, 13, 26, 38),
#   'updated_at': datetime.datetime(2021, 1, 6, 14, 7, 30),
#   'user': 'julienbel',
#   'score': 2},
#  {'number': 18305,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18305',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 16, 7, 20),
#   'created_at': datetime.datetime(2021, 1, 5, 23, 55, 19),
#   'updated_at': datetime.datetime(2021, 1, 6, 16, 7, 21),
#   'user': 'axeliodiaz',
#   'score': 2},
#  {'number': 18290,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18290',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 4,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 20, 14, 34),
#   'created_at': datetime.datetime(2021, 1, 5, 19, 30, 52),
#   'updated_at': datetime.datetime(2021, 1, 5, 20, 14, 35),
#   'user': 'jbasualdo',
#   'score': 2},
#  {'number': 18285,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18285',
#   'commits': 1,
#   'additions': 6,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 19, 27, 24),
#   'created_at': datetime.datetime(2021, 1, 5, 18, 23, 21),
#   'updated_at': datetime.datetime(2021, 1, 5, 19, 27, 25),
#   'user': 'ekauffmann',
#   'score': 2},
#  {'number': 18276,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18276',
#   'commits': 1,
#   'additions': 4,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 18, 9, 40),
#   'created_at': datetime.datetime(2021, 1, 5, 16, 15, 25),
#   'updated_at': datetime.datetime(2021, 1, 5, 18, 9, 41),
#   'user': 'julienbel',
#   'score': 2},
#  {'number': 18270,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18270',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 2,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 45, 11),
#   'created_at': datetime.datetime(2021, 1, 5, 15, 20, 20),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 45, 13),
#   'user': 'plreyes',
#   'score': 2},
#  {'number': 18269,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18269',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 4,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 31, 42),
#   'created_at': datetime.datetime(2021, 1, 5, 15, 15, 58),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 31, 43),
#   'user': 'bixtope',
#   'score': 2},
#  {'number': 18262,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18262',
#   'commits': 1,
#   'additions': 2,
#   'deletions': 2,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 40, 16),
#   'created_at': datetime.datetime(2021, 1, 5, 14, 7, 28),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 40, 18),
#   'user': 'efredz',
#   'score': 2},
#  {'number': 18260,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18260',
#   'commits': 1,
#   'additions': 6,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 14, 2, 26),
#   'created_at': datetime.datetime(2021, 1, 5, 13, 27, 26),
#   'updated_at': datetime.datetime(2021, 1, 5, 14, 8, 22),
#   'user': 'saherp145',
#   'score': 2},
#  {'number': 18254,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18254',
#   'commits': 1,
#   'additions': 19,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 13, 45, 16),
#   'created_at': datetime.datetime(2021, 1, 4, 23, 10, 55),
#   'updated_at': datetime.datetime(2021, 1, 5, 13, 45, 18),
#   'user': 'argenisfd',
#   'score': 2},
#  {'number': 18250,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18250',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 22, 20, 7),
#   'created_at': datetime.datetime(2021, 1, 4, 21, 44, 31),
#   'updated_at': datetime.datetime(2021, 1, 4, 22, 20, 8),
#   'user': 'saherp145',
#   'score': 2},
#  {'number': 18241,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18241',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 19, 59, 48),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 46, 49),
#   'updated_at': datetime.datetime(2021, 1, 4, 19, 59, 49),
#   'user': 'crogel23',
#   'score': 2},
#  {'number': 18238,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18238',
#   'commits': 1,
#   'additions': 7,
#   'deletions': 6,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 6, 16, 8, 11),
#   'created_at': datetime.datetime(2021, 1, 4, 19, 29, 50),
#   'updated_at': datetime.datetime(2021, 1, 6, 16, 8, 12),
#   'user': 'jbasualdo',
#   'score': 2},
#  {'number': 18236,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18236',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 19, 37, 54),
#   'created_at': datetime.datetime(2021, 1, 4, 18, 56, 34),
#   'updated_at': datetime.datetime(2021, 1, 4, 19, 37, 56),
#   'user': 'Sebaatd',
#   'score': 2},
#  {'number': 18229,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18229',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 18, 49, 48),
#   'created_at': datetime.datetime(2021, 1, 4, 17, 21, 40),
#   'updated_at': datetime.datetime(2021, 1, 4, 18, 49, 49),
#   'user': 'faijorquera',
#   'score': 2},
#  {'number': 18228,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18228',
#   'commits': 1,
#   'additions': 0,
#   'deletions': 4,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 18, 23, 47),
#   'created_at': datetime.datetime(2021, 1, 4, 16, 13, 26),
#   'updated_at': datetime.datetime(2021, 1, 4, 18, 23, 48),
#   'user': 'axeliodiaz',
#   'score': 2},
#  {'number': 18227,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18227',
#   'commits': 1,
#   'additions': 18,
#   'deletions': 8,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 20, 13, 10),
#   'created_at': datetime.datetime(2021, 1, 4, 16, 7, 3),
#   'updated_at': datetime.datetime(2021, 1, 4, 20, 13, 11),
#   'user': 'jicortes2',
#   'score': 2},
#  {'number': 18215,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18215',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 13, 52, 41),
#   'created_at': datetime.datetime(2021, 1, 4, 13, 26, 43),
#   'updated_at': datetime.datetime(2021, 1, 4, 14, 3, 9),
#   'user': 'pfariaz',
#   'score': 2},
#  {'number': 18202,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18202',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 4,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 8, 16, 58, 24),
#   'created_at': datetime.datetime(2020, 12, 31, 18, 31),
#   'updated_at': datetime.datetime(2021, 1, 8, 16, 58, 26),
#   'user': 'pgarcia14180',
#   'score': 2},
#  {'number': 18194,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18194',
#   'commits': 1,
#   'additions': 1,
#   'deletions': 1,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 12, 43, 50),
#   'created_at': datetime.datetime(2020, 12, 31, 16, 16, 6),
#   'updated_at': datetime.datetime(2021, 1, 4, 12, 43, 51),
#   'user': 'Nach1n',
#   'score': 2},
#  {'number': 18191,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18191',
#   'commits': 1,
#   'additions': 5,
#   'deletions': 2,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 23, 3),
#   'created_at': datetime.datetime(2020, 12, 31, 15, 46, 56),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 23, 4),
#   'user': 'ivanACL',
#   'score': 2},
#  {'number': 18189,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18189',
#   'commits': 1,
#   'additions': 5,
#   'deletions': 2,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 7, 15, 22, 35),
#   'created_at': datetime.datetime(2020, 12, 31, 15, 40, 11),
#   'updated_at': datetime.datetime(2021, 1, 7, 15, 22, 36),
#   'user': 'ivanACL',
#   'score': 2},
#  {'number': 18173,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/18173',
#   'commits': 1,
#   'additions': 5,
#   'deletions': 8,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 4, 15, 35, 27),
#   'created_at': datetime.datetime(2020, 12, 31, 0, 56, 24),
#   'updated_at': datetime.datetime(2021, 1, 4, 15, 35, 28),
#   'user': 'jbasualdo',
#   'score': 2},
#  {'number': 17531,
#   'url': 'https://github.com/cornershop/cornershop-backend/pull/17531',
#   'commits': 1,
#   'additions': 17,
#   'deletions': 0,
#   'changed_files': 1,
#   'merged_at': datetime.datetime(2021, 1, 5, 15, 21, 10),
#   'created_at': datetime.datetime(2020, 12, 11, 14, 14, 45),
#   'updated_at': datetime.datetime(2021, 1, 5, 15, 21, 11),
#   'user': 'cothidalgo',
#   'score': 2}]
