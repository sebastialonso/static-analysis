# %%
import ast
import os
from operator import itemgetter
from apps.patterns.analyzer import BaseFileAnalyzer
from apps.structure import get_full_path

class ServiceDocAnalyzer(BaseFileAnalyzer):
    def __init__(self, *args, **kwargs):
        self.doc_elements = []
        super(ServiceDocAnalyzer, self).__init__(*args, **kwargs)
        
    def build_doc(self, payload):
        self.doc_elements.append(payload)
    
    def get_analysis(self):
        elements = sorted(self.doc_elements, key=itemgetter('name'))
        avg_score = sum(list(map(lambda x: x["score"], elements))) / len(elements)
        return {
            "services": elements,
            "global": {
                "score": avg_score
            }
        }
    
    def get_function_score(self, payload):
        score = 100
        if not payload.get('has_docstring'):
            score -= 33
            
        arguments = payload.get('arguments', [])
        if len(arguments) > 0:
            missing_args = 0
            for arg in arguments:
                if arg.get("type", "missing") == "missing":
                    missing_args += 1
            score_to_remove = 33*(missing_args/len(arguments)) 
            score -= score_to_remove
        
        if payload.get("return_type") == "missing":
            score -= 33
        return score
    
    def get_processed_type(self, annotation):
        if annotation is None:
            return "missing"
        if annotation.__class__ == ast.Name:
            return annotation.id
        if annotation.__class__ == ast.Attribute:
            return annotation.attr
        if annotation.__class__ == ast.Subscript:
            inner_type = self.get_processed_type(annotation.slice)
            outer_type = self.get_processed_type(annotation.value)
            return f"{outer_type}[{inner_type}]"
        if annotation.__class__ == ast.Str:
            return annotation.s
        if annotation.__class__ == ast.Num:
            raise Exception("oops", annotation, dir(annotation))
        if annotation.__class__ == ast.Constant:
            raise Exception("oops", annotation, dir(annotation))
        if annotation.__class__ == ast.NameConstant:
            return annotation.value
        if annotation.__class__ == ast.Index:
            index_type = self.get_processed_type(annotation.value)
            return index_type
        if annotation.__class__ == ast.Tuple:
            types = []
            for expr in annotation.elts:
                elts_type = self.get_processed_type(expr)
                types.append(elts_type)
            return ", ".join(types)
        raise Exception("oops", annotation, dir(annotation))
        
    def visit_FunctionDef(self, node):
        arguments = [
            {
                "name": arg.arg,
                "type": self.get_processed_type(arg.annotation),
            }
            for arg in node.args.args
        ]
        docstring = ast.get_docstring(node)
        return_type = self.get_processed_type(node.returns)
        payload = dict(
            name=node.name,
            has_docstring=False if docstring is None or docstring == "" else True,
            docstring=docstring,
            arguments=arguments,
            return_type=return_type
        )
        score = self.get_function_score(payload)
        payload["score"] = score
        self.build_doc(payload)
        

file_path = "apps/catalog/services.py"
full_file_path = get_full_path(file_path=file_path)

anlyzr = ServiceDocAnalyzer(entrypoint=full_file_path)
anlyzr.start()
anlyzr.get_analysis()
# Out:
# {'services': [{'name': '__init__',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'user', 'type': 'missing'},
#     {'name': 'lat', 'type': 'missing'},
#     {'name': 'lng', 'type': 'missing'},
#     {'name': 'locality', 'type': 'missing'},
#     {'name': 'country_code', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '__init__',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'product_branch', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '__init__',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '__init__',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_add_stores_popularity',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_add_user_purchases',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'missing'},
#     {'name': 'since', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_get_boolean',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'field', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_get_branch_blacklist',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store_branch', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_get_date',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'field', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_get_date_list',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'}],
#    'return_type': 'list',
#    'score': 50.5},
#   {'name': '_get_range_as_string',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'from_row', 'type': 'int'},
#     {'name': 'from_column', 'type': 'int'},
#     {'name': 'until_row', 'type': 'int'},
#     {'name': 'until_column', 'type': 'int'}],
#    'return_type': 'str',
#    'score': 60.4},
#   {'name': '_get_time',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'field', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_modify_branch_schedules',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'base_schedule', 'type': 'BranchBaseSchedule'}],
#    'return_type': 'missing',
#    'score': 17.5},
#   {'name': '_process_row',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'row_number', 'type': 'int'}],
#    'return_type': 'Tuple[StoreBranch, List[BranchBaseSchedule]]',
#    'score': 56.0},
#   {'name': '_process_row',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'date_list', 'type': 'list'},
#     {'name': 'row_number', 'type': 'int'}],
#    'return_type': 'Tuple[StoreBranch, List[dict]]',
#    'score': 58.75},
#   {'name': '_read_day_schedule',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'row_number', 'type': 'int'},
#     {'name': 'col_number', 'type': 'int'},
#     {'name': 'base_schedule', 'type': 'BranchBaseSchedule'}],
#    'return_type': 'missing',
#    'score': 27.4},
#   {'name': '_read_day_schedule',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'row_number', 'type': 'int'},
#     {'name': 'col_number', 'type': 'int'},
#     {'name': 'branch_schedule', 'type': 'BranchSchedule'}],
#    'return_type': 'missing',
#    'score': 27.4},
#   {'name': '_send_slack_message_active_status_branch_update',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch', 'type': 'missing'},
#     {'name': 'inactive_hotspot', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_send_slack_message_if_no_active_branch_status_update',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch', 'type': 'missing'},
#     {'name': 'zone_multipliers', 'type': 'missing'},
#     {'name': 'exclusive_hotspot_multipliers', 'type': 'missing'},
#     {'name': 'hotspot', 'type': 'missing'},
#     {'name': 'zone_guarantees', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_serialize_store',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_set_stores_extra_data',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'List[dict]'},
#     {'name': 'since', 'type': 'str'}],
#    'return_type': 'missing',
#    'score': 23.0},
#   {'name': '_set_user_allowed_flags',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': '_validate_headers',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'}],
#    'return_type': 'missing',
#    'score': 17.5},
#   {'name': '_validate_headers',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'}],
#    'return_type': 'missing',
#    'score': 17.5},
#   {'name': 'add_product_barcode',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_id', 'type': 'missing'},
#     {'name': 'barcode', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'amount_with_taxes_for_canada',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'amount', 'type': 'Decimal'},
#     {'name': 'city_code', 'type': 'str'},
#     {'name': 'taxable_category_name', 'type': 'str'}],
#    'return_type': 'Decimal',
#    'score': 67.0},
#   {'name': 'append_price_data',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product', 'type': 'missing'},
#     {'name': 'branch_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'assign_tags_to_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product', 'type': 'Product'},
#     {'name': 'tags', 'type': 'List[str]'}],
#    'return_type': None,
#    'score': 67.0},
#   {'name': 'branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'branches_data',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'build_product_branch_from_supply_product_branch',
#    'has_docstring': True,
#    'docstring': 'Build product branches with supply information\n\n:param product: catalog product instance\n:param supply_product_branch: supply product branch instance\n:param country: Store country code',
#    'arguments': [{'name': 'product', 'type': 'missing'},
#     {'name': 'supply_product_branch', 'type': 'missing'},
#     {'name': 'country', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'change_product_buy_unit',
#    'has_docstring': True,
#    'docstring': "We can't change a product's buy unit because it will create inconsistencies in the shopper app when a product\nwas ordered using the old buy_unit but the picking is made using the new buy_unit. This function changes the\nbuy_unit of a product by copying the original product, changing the buy_unit in the copy and disabling the original\nproduct. Also changes all relevant references to the original product.",
#    'arguments': [{'name': 'product_id', 'type': 'missing'},
#     {'name': 'buy_unit', 'type': 'missing'},
#     {'name': 'variable_weight', 'type': 'missing'},
#     {'name': 'unit_conversion_rate', 'type': 'missing'},
#     {'name': 'package', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'check_availability_status_schedule_exists_for_product_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_branch', 'type': 'int'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'check_store_branch_exists',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'}],
#    'return_type': 'bool',
#    'score': 67.0},
#   {'name': 'check_stores_exists_for_location_v2',
#    'has_docstring': True,
#    'docstring': 'Returns a boolean if any active store with storebranch exists in an OpZone given the lat,lng parameters',
#    'arguments': [{'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'count_feasible_product_branches',
#    'has_docstring': True,
#    'docstring': 'Returns the amount of product branches filtered by StoreBranch and Product excluding\n`out of stock` and `discontinued` statuses.',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'product_ids', 'type': 'List[int]'}],
#    'return_type': 'int',
#    'score': 100.0},
#   {'name': 'create_barcode_scan',
#    'has_docstring': True,
#    'docstring': 'Returns a new BarcodeScan. ',
#    'arguments': [{'name': 'product_id', 'type': 'int'},
#     {'name': 'shopper_id', 'type': 'int'},
#     {'name': 'barcode', 'type': 'str'}],
#    'return_type': 'Optional[BarcodeScanDataClass]',
#    'score': 100.0},
#   {'name': 'create_catalog_context',
#    'has_docstring': True,
#    'docstring': 'Return a new CatalogContext with the specified parameters of has_subscription, user_id and/or language',
#    'arguments': [{'name': 'has_subscription', 'type': 'bool'},
#     {'name': 'user_id', 'type': 'int'},
#     {'name': 'language', 'type': 'str'}],
#    'return_type': 'CatalogContext',
#    'score': 100.0},
#   {'name': 'create_catalog_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'brand_name', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'create_missing_product_branches_for_supply_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'supply_product', 'type': 'ProductData'},
#     {'name': 'last_visited', 'type': 'Optional[datetime]'},
#     {'name': 'catalog_store_branch_ids_to_create',
#      'type': 'Optional[List[int]]'},
#     {'name': 'consider_store_branch_active', 'type': 'bool'}],
#    'return_type': 'List[ProductBranch]',
#    'score': 67.0},
#   {'name': 'create_product_branches_on_store_branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product', 'type': 'missing'},
#     {'name': 'price', 'type': 'missing'},
#     {'name': 'store_branch_ids', 'type': 'missing'},
#     {'name': 'availability_status', 'type': 'missing'},
#     {'name': 'active', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'create_product_stock_review',
#    'has_docstring': True,
#    'docstring': 'Generates shoppertasks (ProductStockReviewTask) to evaluate a specific product branch stock level\nArgs:\n    product_branch_ids: Ids of product branches to evaluate\n    user_ids: users that are going to receive the task\n\nReturns: None',
#    'arguments': [{'name': 'product_branch_ids', 'type': 'List[int]'},
#     {'name': 'user_ids', 'type': 'List[int]'}],
#    'return_type': 'missing',
#    'score': 67.0},
#   {'name': 'delete_products_store_for_catalog_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'catalog_product_id', 'type': 'int'},
#     {'name': 'store_id', 'type': 'Optional[int]'}],
#    'return_type': None,
#    'score': 67.0},
#   {'name': 'does_other_active_external_store_branch_by_city_and_store_exists',
#    'has_docstring': True,
#    'docstring': 'Returns True if there is any other active and not internal StoreBranch\n(excluding store_branch_id), filtered by city and store. False in any other case.',
#    'arguments': [{'name': 'store_branch_id', 'type': 'missing'},
#     {'name': 'city_id', 'type': 'int'},
#     {'name': 'store_id', 'type': 'int'}],
#    'return_type': 'bool',
#    'score': 89.0},
#   {'name': 'exists_active_store_in_location_v2',
#    'has_docstring': True,
#    'docstring': 'Checks whether or not the store with store_id is available for the location given by lat and lng',
#    'arguments': [{'name': 'store_id', 'type': 'int'},
#     {'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'exists_product_by_id',
#    'has_docstring': True,
#    'docstring': 'Return if a Product exist by product_id',
#    'arguments': [{'name': 'id', 'type': 'int'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'exists_store_parameters_by_store_and_parameter',
#    'has_docstring': True,
#    'docstring': 'Checks if StoreParameter filtered by store and parameter exists. ',
#    'arguments': [{'name': 'store_uuid', 'type': 'Union[str, UUID]'},
#     {'name': 'parameter', 'type': 'str'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'fetch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'branch_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'fetch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'geohash', 'type': 'Text'},
#     {'name': 'branch_id', 'type': 'int'},
#     {'name': 'language', 'type': 'Text'},
#     {'name': 'with_blocked_slots', 'type': 'Optional[bool]'},
#     {'name': 'express_delivery', 'type': 'bool'}],
#    'return_type': 'missing',
#    'score': 28.5},
#   {'name': 'filter_new_stores',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_ids_list', 'type': 'List[int]'},
#     {'name': 'max_items', 'type': 'int'}],
#    'return_type': 'List[int]',
#    'score': 67.0},
#   {'name': 'filter_stores_weekly_orders_count',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_ids', 'type': 'List[int]'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'find_existing_products',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'supply_product_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'find_existing_products_by_barcodes',
#    'has_docstring': True,
#    'docstring': 'Returns a list of existing catalog products that are similar to a given product information.\n\nNotes\n-----\nThe returned list of similar catalog products are ordered in a descending manner according to their similarity score.\n\nParameters\n----------\nbarcodes_list: list of str\n    List of barcodes related to the given product\ncurrency: str\n    Currency of the given product\nbrand_name: str\n    Brand name of the given product\nproduct_name: str\n    Name of the given product\n\nReturns\n-------\nsimilar_products: list of tuples of (shopping.apps.catalog.Product, float)\n    List of similar products',
#    'arguments': [{'name': 'barcodes_list', 'type': 'missing'},
#     {'name': 'currency', 'type': 'missing'},
#     {'name': 'brand_name', 'type': 'missing'},
#     {'name': 'product_name', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'find_product_branch_by_barcode',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'barcode', 'type': 'missing'},
#     {'name': 'context', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'find_product_by_barcode',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'currency', 'type': 'missing'},
#     {'name': 'barcodes', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'format_breakdown_tax',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'tax_name', 'type': 'missing'},
#     {'name': 'tax_rate', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'generate_featured_categories_for_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'forced_localization', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'generate_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store_branches', 'type': 'Iterable[StoreBranch]'}],
#    'return_type': 'NamedTemporaryFile',
#    'score': 50.5},
#   {'name': 'generate_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store_branches', 'type': 'Iterable[StoreBranch]'}],
#    'return_type': 'NamedTemporaryFile',
#    'score': 50.5},
#   {'name': 'generate_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store_branches', 'type': 'Iterable[StoreBranch]'},
#     {'name': 'from_date', 'type': 'datetime'},
#     {'name': 'until_date', 'type': 'datetime'}],
#    'return_type': 'NamedTemporaryFile',
#    'score': 58.75},
#   {'name': 'generate_request_store_profile_update',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_active_order_store_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'order', 'type': 'Order'}],
#    'return_type': 'Dict',
#    'score': 67.0},
#   {'name': 'get_active_shopper_count',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'city_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_active_store_branch_ids_by_city_id_and_order_location',
#    'has_docstring': True,
#    'docstring': 'Returns a list of StoreBranch ids filtered by city id and, lat, lng and max_distance from the order or None',
#    'arguments': [{'name': 'city_id', 'type': 'int'},
#     {'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'},
#     {'name': 'max_distance', 'type': 'Optional[int]'}],
#    'return_type': 'List[int]',
#    'score': 100.0},
#   {'name': 'get_active_store_branches_by_city',
#    'has_docstring': True,
#    'docstring': 'Return all active store branches for the city.',
#    'arguments': [{'name': 'city_id', 'type': 'int'}],
#    'return_type': 'List[StoreBranch]',
#    'score': 100.0},
#   {'name': 'get_active_store_branches_by_store_id',
#    'has_docstring': True,
#    'docstring': 'Returns a List of StoreBranch by its store_id, otherwise empty List ',
#    'arguments': [{'name': 'store_id', 'type': 'int'}],
#    'return_type': 'List[StoreBranch]',
#    'score': 100.0},
#   {'name': 'get_active_store_by_name_and_country',
#    'has_docstring': True,
#    'docstring': 'Return the active store from replica-catalog db based on the name (exact match)\nRaises:\n    CatalogServiceError: If the store with store_id does not exist',
#    'arguments': [{'name': 'name', 'type': 'str'},
#     {'name': 'country_code', 'type': 'str'}],
#    'return_type': 'Store',
#    'score': 100.0},
#   {'name': 'get_active_stores_for_location_v2',
#    'has_docstring': True,
#    'docstring': 'Returns a list of StoreDataClass with the active stores with storebranches in an OpZone given by the lat,lng parameters',
#    'arguments': [{'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'}],
#    'return_type': 'List[StoreDataClass]',
#    'score': 100.0},
#   {'name': 'get_aggregated_product_regulatory_fee',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch', 'type': 'int'},
#     {'name': 'products_quantities', 'type': 'Dict[int, float]'},
#     {'name': 'scope', 'type': 'str'}],
#    'return_type': 'Dict',
#    'score': 67.0},
#   {'name': 'get_aggregated_product_taxes',
#    'has_docstring': True,
#    'docstring': 'get_aggregated_product_taxes(store_branch_id, {product_id: quantity})\nreturn {\n    "IVA (19%)": Decimal(12.12),\n    "HST (7%)": Decimal(7.23)\n}',
#    'arguments': [{'name': 'store_branch', 'type': 'missing'},
#     {'name': 'products_quantities', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_aisles_by_promotional_department_and_branch',
#    'has_docstring': True,
#    'docstring': 'Returns a List of PromotionalAisleData by a promotional_department, branch_id and some filters',
#    'arguments': [{'name': 'promotional_department', 'type': 'missing'},
#     {'name': 'branch_id', 'type': 'int'},
#     {'name': 'include_empty', 'type': 'bool'},
#     {'name': 'catalog_context', 'type': 'CatalogContext'},
#     {'name': 'sort_by', 'type': 'Optional[List[str]]'}],
#    'return_type': 'List[PromotionalAisleData]',
#    'score': 93.4},
#   {'name': 'get_availability_schedule_by_product_branch_and_schedule_date',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_branch', 'type': 'int'},
#     {'name': 'scheduled_at', 'type': 'datetime'}],
#    'return_type': 'List[ProductBranchAvailabilityStatusSchedule]',
#    'score': 67.0},
#   {'name': 'get_available_branches_by_timezone_city_and_store',
#    'has_docstring': True,
#    'docstring': 'Returns a list if store branches data that will be active in the given zone. ',
#    'arguments': [{'name': 'timezone', 'type': 'str'},
#     {'name': 'city_id', 'type': 'int'},
#     {'name': 'store_id', 'type': 'int'},
#     {'name': 'minutes_before_close', 'type': 'int'}],
#    'return_type': 'List[StoreBranchWithLocation]',
#    'score': 100.0},
#   {'name': 'get_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_area_multi_polygon',
#    'has_docstring': True,
#    'docstring': 'Generates a multi-polygon that can be used as the availability area for a store in a city',
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'radius', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_branch_base_schedule_by_store_branch_id_and_day_of_week_from_master',
#    'has_docstring': True,
#    'docstring': 'Uses default database to allow updates on the BranchBaseSchedule',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'day_of_week', 'type': 'int'}],
#    'return_type': 'BranchBaseSchedule',
#    'score': 100.0},
#   {'name': 'get_branch_base_schedule_from_id',
#    'has_docstring': True,
#    'docstring': 'Return the BranchBaseSchedule from branch_base_schedule_id\nRaises:\nCatalogServiceError: If something goes wrong here, this exception will be raised',
#    'arguments': [{'name': 'id', 'type': 'int'}],
#    'return_type': 'Optional[BranchBaseSchedule]',
#    'score': 100.0},
#   {'name': 'get_branch_contact_info',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_featured_content',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'audience_types', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_featured_content_traceable',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'audience_types', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_free_delivery_for_checkout',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'user', 'type': 'missing'},
#     {'name': 'firebase_cart', 'type': 'missing'},
#     {'name': 'features_enabled', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_limited_availability',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'timezone', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_newest_products_serialized',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'},
#     {'name': 'has_subscription', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branch_schedule_from_id',
#    'has_docstring': True,
#    'docstring': 'Return the BranchSchedule from branch_schedule_id\n\nRaises:\nCatalogServiceError: If something goes wrong here, this exception will be raised',
#    'arguments': [{'name': 'id', 'type': 'int'}],
#    'return_type': 'Optional[BranchSchedule]',
#    'score': 100.0},
#   {'name': 'get_branch_schedules_by_store_branch_ids_and_date',
#    'has_docstring': True,
#    'docstring': 'Return a dictionary of branch_id -> branch_schedule given a list of store branch ids for a specific date',
#    'arguments': [{'name': 'store_branch_ids', 'type': 'List[int]'},
#     {'name': 'from_date', 'type': 'date'}],
#    'return_type': 'Dict[int, BranchSchedule]',
#    'score': 100.0},
#   {'name': 'get_branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'branch_ids', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_id', 'type': 'missing'},
#     {'name': 'city', 'type': 'missing'},
#     {'name': 'zone', 'type': 'missing'},
#     {'name': 'active_only', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branches_data',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'geohash', 'type': 'missing'},
#     {'name': 'visible_statuses', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_branches_display_name_by_branches_id',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_ids', 'type': 'List[int]'}],
#    'return_type': 'Dict[int, str]',
#    'score': 67.0},
#   {'name': 'get_branches_forced_locale_for_cities_by_country',
#    'has_docstring': True,
#    'docstring': 'Returns a tuple of city_id with their locale for a given country,\nusing forced localization store branch parameter, uses distinct on city_id',
#    'arguments': [{'name': 'country', 'type': 'str'}],
#    'return_type': 'List[Tuple[str]]',
#    'score': 100.0},
#   {'name': 'get_brand_by_id',
#    'has_docstring': True,
#    'docstring': 'Returns an instance of BrandDataClass by its brand_id otherwise raises a BrandDoesNotExist exception\nRaises:\n    BrandDoesNotExist: if the provided `brand_id` was not found.',
#    'arguments': [{'name': 'brand_id', 'type': 'int'}],
#    'return_type': 'BrandDataClass',
#    'score': 100.0},
#   {'name': 'get_brand_pk_list_for_products',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'products', 'type': 'List[Product]'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_brands_by_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of Brand instances filtered by `brand_ids`',
#    'arguments': [{'name': 'brand_ids', 'type': 'List[int]'}],
#    'return_type': 'List[Brand]',
#    'score': 100.0},
#   {'name': 'get_brands_by_pk',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'brand_pk_list', 'type': 'List[str]'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_brands_values_by_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of dictionaries of Brand values filtered by `brand_id`',
#    'arguments': [{'name': 'brand_ids', 'type': 'List[int]'},
#     {'name': 'values', 'type': 'Set[str]'}],
#    'return_type': 'List[Dict[str, Any]]',
#    'score': 100.0},
#   {'name': 'get_cached_delivery_slots_for_branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_ids', 'type': 'List[int]'},
#     {'name': 'zone_id', 'type': 'int'},
#     {'name': 'geohash', 'type': 'str'},
#     {'name': 'language', 'type': 'str'},
#     {'name': 'express_delivery', 'type': 'bool'},
#     {'name': 'only_first_slot_available', 'type': 'bool'},
#     {'name': 'include_blocked_slots', 'type': 'bool'}],
#    'return_type': 'Dict',
#    'score': 67.0},
#   {'name': 'get_cached_delivery_slots_in_bulk',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_ids', 'type': 'List[int]'},
#     {'name': 'zone_id', 'type': 'int'},
#     {'name': 'geohash', 'type': 'str'},
#     {'name': 'language', 'type': 'str'},
#     {'name': 'express_delivery', 'type': 'bool'}],
#    'return_type': 'Dict',
#    'score': 67.0},
#   {'name': 'get_candidate_branch_for_order',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'order', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_catalog_context',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'language', 'type': 'Optional[str]'}],
#    'return_type': 'CatalogContext',
#    'score': 67.0},
#   {'name': 'get_catalog_context_for_user',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'user', 'type': 'User'}],
#    'return_type': 'CatalogContext',
#    'score': 67.0},
#   {'name': 'get_catalog_instructions_by_product_ids_and_store_branch_id',
#    'has_docstring': True,
#    'docstring': 'Returns a dictionary of product instructions their ID as the key. ',
#    'arguments': [{'name': 'product_ids', 'type': 'List[int]'},
#     {'name': 'store_branch_id', 'type': 'int'}],
#    'return_type': 'Dict[int, str]',
#    'score': 100.0},
#   {'name': 'get_category_and_descendant_slugs',
#    'has_docstring': True,
#    'docstring': "Return a list of categories and related descendants slugs that match it's slug/name from a given list",
#    'arguments': [{'name': 'categories', 'type': 'List[str]'},
#     {'name': 'excluded_keywords', 'type': 'Optional[List[str]]'}],
#    'return_type': 'List[str]',
#    'score': 100.0},
#   {'name': 'get_cities_for_branches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branches', 'type': 'QuerySet'}],
#    'return_type': 'QuerySet',
#    'score': 67.0},
#   {'name': 'get_closed_branches_ids_at_datetime',
#    'has_docstring': True,
#    'docstring': 'This function returns a list of branches_ids that are active but closed at\nthe given datetime.\nif not datetime is given then the current datetime at UTC is used',
#    'arguments': [{'name': 'at_datetime', 'type': 'Optional[datetime]'}],
#    'return_type': 'List[int]',
#    'score': 100.0},
#   {'name': 'get_closest_store_branch',
#    'has_docstring': True,
#    'docstring': 'Returns the closest StoreBranch to the position formed by (lng, lat).\nBy passing city_id, the closest StoreBranch within the given city will be returned',
#    'arguments': [{'name': 'lng', 'type': 'float'},
#     {'name': 'lat', 'type': 'float'},
#     {'name': 'city_id', 'type': 'Optional[int]'}],
#    'return_type': 'Optional[StoreBranch]',
#    'score': 100.0},
#   {'name': 'get_collections',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'store_ids', 'type': 'missing'},
#     {'name': 'country_code', 'type': 'missing'},
#     {'name': 'language', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_collections_weekly_orders_count',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [],
#    'return_type': 'missing',
#    'score': 34},
#   {'name': 'get_current_order_count',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'city_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_delivery_taxes',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch', 'type': 'missing'},
#     {'name': 'delivery_fee', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_equivalent_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'Optional[str]'},
#     {'name': 'lat', 'type': 'Optional[float]'},
#     {'name': 'lng', 'type': 'Optional[float]'},
#     {'name': 'locality', 'type': 'str'},
#     {'name': 'country', 'type': 'str'},
#     {'name': 'store_id', 'type': 'Optional[str]'},
#     {'name': 'user_id', 'type': 'Optional[str]'},
#     {'name': 'stripped', 'type': 'bool'}],
#    'return_type': 'Tuple[int, Dict]',
#    'score': 67.0},
#   {'name': 'get_featured_categories',
#    'has_docstring': True,
#    'docstring': "Takes a list of FeaturedCategoryTrees and:\n1. Moves FeaturedCategoryTrees with weight less than CATEGORY_MIN_PRODUCTS to 'other_category'\n2. Sorts the remaining FeaturedCategoryTrees by popularity",
#    'arguments': [{'name': 'category_trees', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_featured_stores_configs_by_city',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'city_code', 'type': 'str'}],
#    'return_type': 'Dict[int, Dict]',
#    'score': 67.0},
#   {'name': 'get_first_collection_for_store_by_country',
#    'has_docstring': True,
#    'docstring': 'Returns the first collections for each store of a given Country.\nUses distinct on store_id',
#    'arguments': [{'name': 'country', 'type': 'str'}],
#    'return_type': 'Dict[int, int]',
#    'score': 100.0},
#   {'name': 'get_first_store_collection_id',
#    'has_docstring': True,
#    'docstring': 'Returns the first id of StoreCollection or None if does not exist',
#    'arguments': [],
#    'return_type': 'int',
#    'score': 100},
#   {'name': 'get_first_storebranch_by_store_id',
#    'has_docstring': True,
#    'docstring': 'Return the StoreBranch from store_id or None if does not exist',
#    'arguments': [{'name': 'id', 'type': 'int'}],
#    'return_type': 'Optional[StoreBranch]',
#    'score': 100.0},
#   {'name': 'get_free_delivery_campaign_for_checkout',
#    'has_docstring': True,
#    'docstring': 'Returns the free delivery campaign if it corresponds at pre_checkout time\n\nArgs:\n    branch_id: id of the branch as integer\n    user: User, we need to know the user to match with the audience\n    products: products dictionary as they come from the firebase cart\n\nReturns:\n    int: free delivery campaign id if any',
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'user', 'type': 'missing'},
#     {'name': 'products', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_groups',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'audience_types', 'type': 'missing'},
#     {'name': 'force_categories', 'type': 'missing'},
#     {'name': 'include_inactive_cities', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_heavy_categories_by_store',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [],
#    'return_type': 'missing',
#    'score': 34},
#   {'name': 'get_humanized_buy_unit_short',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'buy_unit', 'type': 'str'}],
#    'return_type': 'str',
#    'score': 67.0},
#   {'name': 'get_last_week_store_orders_count_by_city',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_id', 'type': 'int'},
#     {'name': 'city_code', 'type': 'str'}],
#    'return_type': 'Optional[int]',
#    'score': 67.0},
#   {'name': 'get_nearest_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_id', 'type': 'str'},
#     {'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'},
#     {'name': 'visible_statuses', 'type': 'List[str]'}],
#    'return_type': 'Optional[StoreBranch]',
#    'score': 67.0},
#   {'name': 'get_next_product_to_scan',
#    'has_docstring': True,
#    'docstring': 'Returns the corresponding next product to be scanned. ',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'shopper_id', 'type': 'int'},
#     {'name': 'product_ids_to_skip', 'type': 'List[int]'},
#     {'name': 'add_categories_condition', 'type': 'bool'}],
#    'return_type': 'Dict[str, Any]',
#    'score': 100.0},
#   {'name': 'get_no_results_searches',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_ids', 'type': 'missing'},
#     {'name': 'blacklisted', 'type': 'missing'},
#     {'name': 'date_from', 'type': 'missing'},
#     {'name': 'date_to', 'type': 'missing'},
#     {'name': 'currency', 'type': 'missing'},
#     {'name': 'group', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_or_create_brand',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'brand_name', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'product_id', 'type': 'missing'},
#     {'name': 'context', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_product_branch',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'product_id', 'type': 'missing'},
#     {'name': 'subscription', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_product_branch_by_branch_id_and_product_id',
#    'has_docstring': True,
#    'docstring': 'Returns an instance of ProductBranchDataClass by its branch_id and its product_id,\n    otherwise raises ProductBranchDoesNotExist exception.\nRaises:\n    ProductBranchDoesNotExist: if no ProductBranch with the provided `store_branch_id` and product_id` was found.',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'product_id', 'type': 'int'}],
#    'return_type': 'ProductBranchDataClass',
#    'score': 100.0},
#   {'name': 'get_product_branch_by_store_branch_and_product',
#    'has_docstring': True,
#    'docstring': 'Returns a ProductBranch by StoreBranch and Product IDs. ',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'product_id', 'type': 'int'}],
#    'return_type': 'Optional[ProductBranch]',
#    'score': 100.0},
#   {'name': 'get_product_branches_by_branch_id_and_product_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of ProductBranch filtered by `branch_id` and `product_ids`',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'product_ids', 'type': 'List[int]'}],
#    'return_type': 'List[ProductBranch]',
#    'score': 100.0},
#   {'name': 'get_product_branches_by_uuids',
#    'has_docstring': True,
#    'docstring': 'Service to get dict with product branches, using as key the product uuid\n:param branch_uuid: str\n:param product_uuid_list: List[str]\n:return: dict',
#    'arguments': [{'name': 'branch_uuid', 'type': 'str'},
#     {'name': 'product_uuid_list', 'type': 'List[str]'}],
#    'return_type': 'Dict',
#    'score': 100.0},
#   {'name': 'get_product_branches_for_recommendations',
#    'has_docstring': True,
#    'docstring': 'Returns product branches for recommended products, filtering by branch ID. ',
#    'arguments': [{'name': 'recommended_product_ids',
#      'type': 'Union[Set[int], List[int]]'},
#     {'name': 'branch_id', 'type': 'int'}],
#    'return_type': 'List[ProductBranch]',
#    'score': 100.0},
#   {'name': 'get_product_branches_values_by_product_id',
#    'has_docstring': True,
#    'docstring': 'Returns optional values from ProductBranches identified by product_id.\nResults are sorted by branch__store_id and branch__name',
#    'arguments': [{'name': 'product_id', 'type': 'int'},
#     {'name': 'values', 'type': 'Set[str]'}],
#    'return_type': 'List[Dict[str, Any]]',
#    'score': 100.0},
#   {'name': 'get_product_branches_values_by_product_id_and_polygon_intersected',
#    'has_docstring': True,
#    'docstring': 'Returns optional values from ProductBranches identified by product_id and whose branches intersect the supplied polygon.\nResults are sorted by branch__store_id and branch__name',
#    'arguments': [{'name': 'product_id', 'type': 'int'},
#     {'name': 'polygon', 'type': 'MultiPolygon'},
#     {'name': 'values', 'type': 'Set[str]'}],
#    'return_type': 'List[Dict[str, Any]]',
#    'score': 100.0},
#   {'name': 'get_product_branches_values_by_store_branch_id_and_product_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of dictionaries of ProductBranch values filtered by `branch_id` and `product_ids`',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'product_ids', 'type': 'List[int]'},
#     {'name': 'values', 'type': 'Set[str]'}],
#    'return_type': 'List[Dict[str, Any]]',
#    'score': 100.0},
#   {'name': 'get_product_by_id',
#    'has_docstring': True,
#    'docstring': 'Returns an instance of ProductDataClass by its product_id, otherwise raises a ProductDoesNotExist exception\nRaises:\n    ProductDoesNotExist: if the provided `product_id` was not found.',
#    'arguments': [{'name': 'product_id', 'type': 'int'}],
#    'return_type': 'Optional[ProductDataClass]',
#    'score': 100.0},
#   {'name': 'get_product_by_uuid',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_uuid', 'type': 'Union[str, UUID]'}],
#    'return_type': 'Product',
#    'score': 67.0},
#   {'name': 'get_product_categories_slugs_by_product_id',
#    'has_docstring': True,
#    'docstring': 'Returns a list of category and parent category slugs related to a product ID',
#    'arguments': [{'name': 'product_id', 'type': 'int'}],
#    'return_type': 'List[str]',
#    'score': 100.0},
#   {'name': 'get_product_family',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'int'},
#     {'name': 'product_id', 'type': 'int'},
#     {'name': 'user', 'type': 'User'}],
#    'return_type': 'ProductFamilyData',
#    'score': 67.0},
#   {'name': 'get_product_list_from_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of Products given a list of product ids. ',
#    'arguments': [{'name': 'product_ids', 'type': 'List[str]'}],
#    'return_type': 'List[Product]',
#    'score': 100.0},
#   {'name': 'get_product_position',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_uuid', 'type': 'UUID'},
#     {'name': 'store_branch_uuid', 'type': 'UUID'}],
#    'return_type': 'Dict',
#    'score': 67.0},
#   {'name': 'get_product_similarity_index',
#    'has_docstring': True,
#    'docstring': 'Computes a similarity score between an existing product and a new product.\n\nNotes\n-----\nSimilarity score is 1.0 when the existing product is the same as the new product.\n\nParameters\n----------\nexisting_product: shopping.apps.catalog.Product\n    Existing product\nnew_product_brand: str, optional\n    New product brand (the default is None)\nnew_product_name: str, optional\n    New product name (the default is None)\nnew_product_package: str, optional\n    New product package (the default is None)\n\nReturns\n-------\nsimilarity: float\n    Similarity index',
#    'arguments': [{'name': 'existing_product', 'type': 'missing'},
#     {'name': 'new_product_brand', 'type': 'missing'},
#     {'name': 'new_product_name', 'type': 'missing'},
#     {'name': 'new_product_package', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_product_store_values_by_product_id',
#    'has_docstring': True,
#    'docstring': 'Returns optional values from ProductStores identified by any id present in `id_list`',
#    'arguments': [{'name': 'product_id', 'type': 'int'},
#     {'name': 'values', 'type': 'Set[str]'}],
#    'return_type': 'List[Dict[str, Any]]',
#    'score': 100.0},
#   {'name': 'get_product_stores_by_store_id',
#    'has_docstring': True,
#    'docstring': 'Returns a list of Product Stores given a store_id ',
#    'arguments': [{'name': 'store_id', 'type': 'int'}],
#    'return_type': 'List[ProductStore]',
#    'score': 100.0},
#   {'name': 'get_productbranch_from_id',
#    'has_docstring': True,
#    'docstring': 'Return the ProductBranch from product_branch_id\nRaises:\nCatalogServiceError: If something goes wrong here, this exception will be raised',
#    'arguments': [{'name': 'id', 'type': 'int'}],
#    'return_type': 'Optional[ProductBranch]',
#    'score': 100.0},
#   {'name': 'get_products',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'int'},
#     {'name': 'product_ids', 'type': 'List[int]'},
#     {'name': 'context', 'type': 'Optional[Dict]'},
#     {'name': 'filter_active', 'type': 'bool'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_products_by_brand_ids',
#    'has_docstring': True,
#    'docstring': 'Returns a list of Products whose brand_id is present in `brand_ids`',
#    'arguments': [{'name': 'brand_ids', 'type': 'List[int]'}],
#    'return_type': 'List[Product]',
#    'score': 100.0},
#   {'name': 'get_products_by_brand_ids_from_master',
#    'has_docstring': True,
#    'docstring': 'Returns a list of Products whose brand_id is present in `brand_ids`. Fetches from default database',
#    'arguments': [{'name': 'brand_ids', 'type': 'List[int]'}],
#    'return_type': 'List[Product]',
#    'score': 100.0},
#   {'name': 'get_products_by_pk',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_pk_list', 'type': 'List[str]'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_products_by_uuid',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_uuid_list', 'type': 'List[str]'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'get_products_popularity_by_store_branch_and_promotion',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'promotion_id', 'type': 'int'}],
#    'return_type': 'Optional[int]',
#    'score': 67.0},
#   {'name': 'get_promotional_departments_for_checkout',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_ids', 'type': 'missing'},
#     {'name': 'product_ids', 'type': 'missing'},
#     {'name': 'audience_types', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_promotional_product_branches_by_branch_and_aisles',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'aisle_ids', 'type': 'missing'},
#     {'name': 'promotional_department_id', 'type': 'missing'},
#     {'name': 'limit', 'type': 'missing'},
#     {'name': 'sort_by', 'type': 'missing'},
#     {'name': 'sort_asc', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_recent_products',
#    'has_docstring': False,
#    'docstring': None,
# ...
#     {'name': 'country', 'type': 'missing'},
#     {'name': 'zone', 'type': 'missing'},
#     {'name': 'user', 'type': 'missing'},
#     {'name': 'audience_types', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_stores_groups',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'lat', 'type': 'missing'},
#     {'name': 'lng', 'type': 'missing'},
#     {'name': 'locality', 'type': 'missing'},
#     {'name': 'country_code', 'type': 'missing'},
#     {'name': 'user', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_stores_mapped_by_store_branch_ids',
#    'has_docstring': True,
#    'docstring': 'Return a dictionary of stores mapped by store brnach ID for a given list of store branch ids.',
#    'arguments': [{'name': 'store_branch_ids', 'type': 'List[int]'}],
#    'return_type': 'Dict[int, Store]',
#    'score': 100.0},
#   {'name': 'get_stores_mapped_in_bulk',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_ids', 'type': 'Set[int]'}],
#    'return_type': 'Dict[int, Store]',
#    'score': 67.0},
#   {'name': 'get_stores_uuids_and_names_with_country_list',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [],
#    'return_type': 'List[Tuple[UUID, str]]',
#    'score': 67},
#   {'name': 'get_stores_weekly_orders_count',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [],
#    'return_type': 'missing',
#    'score': 34},
#   {'name': 'get_stores_with_active_store_branch',
#    'has_docstring': True,
#    'docstring': 'Returns list of StoreDataClass that have any active StoreBranch ',
#    'arguments': [],
#    'return_type': 'List[StoreDataClass]',
#    'score': 100},
#   {'name': 'get_striped_stores_for_location',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'lat', 'type': 'float'},
#     {'name': 'lng', 'type': 'float'},
#     {'name': 'locality', 'type': 'str'},
#     {'name': 'country', 'type': 'str'},
#     {'name': 'user', 'type': 'User'}],
#    'return_type': 'Iterable',
#    'score': 67.0},
#   {'name': 'get_style',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'stores', 'type': 'missing'},
#     {'name': 'force_list', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_taxes_breakdown',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch', 'type': 'missing'},
#     {'name': 'branch_cart', 'type': 'missing'},
#     {'name': 'service_fee', 'type': 'missing'},
#     {'name': 'delivery_fee', 'type': 'missing'},
#     {'name': 'currency', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_taxes_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch', 'type': 'missing'},
#     {'name': 'branch_cart', 'type': 'missing'},
#     {'name': 'currency', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_top_active_stores_by_city',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'city_id', 'type': 'int'},
#     {'name': 'top', 'type': 'int'}],
#    'return_type': 'List[StoreDataClass]',
#    'score': 67.0},
#   {'name': 'get_top_active_stores_by_country',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'country_code', 'type': 'str'},
#     {'name': 'top', 'type': 'int'}],
#    'return_type': 'List[StoreDataClass]',
#    'score': 67.0},
#   {'name': 'get_top_longtail_stores_by_city_or_country',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'country_code', 'type': 'Optional[str]'},
#     {'name': 'city_name', 'type': 'Optional[str]'},
#     {'name': 'limit', 'type': 'int'}],
#    'return_type': 'List[StoreDataClass]',
#    'score': 67.0},
#   {'name': 'get_top_products_for_campaign',
#    'has_docstring': True,
#    'docstring': 'Returns a list of dictionaries representing the ProductBranch by its\ncampaign_id and branch_id',
#    'arguments': [{'name': 'campaign_id', 'type': 'int'},
#     {'name': 'branch_id', 'type': 'int'},
#     {'name': 'catalog_context', 'type': 'missing'},
#     {'name': 'products_sort_by', 'type': 'missing'},
#     {'name': 'products_sort_asc', 'type': 'missing'},
#     {'name': 'limit', 'type': 'missing'}],
#    'return_type': 'List[Dict]',
#    'score': 78.0},
#   {'name': 'get_unfeatureable_stores',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'branches_ids', 'type': 'List[int]'}],
#    'return_type': 'List[int]',
#    'score': 50.5},
#   {'name': 'get_user_featured_stores',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'missing'},
#     {'name': 'user_popular_stores_limit', 'type': 'missing'},
#     {'name': 'include_inactive', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_user_new_stores',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'get_user_recent_stores',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'stores', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'has_alcohol',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'has_product_regulatory_fee',
#    'has_docstring': True,
#    'docstring': 'Returns True if at least one of the products of new_product_ids has regulatory fee, otherwise False',
#    'arguments': [{'name': 'new_product_ids', 'type': 'List[int]'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'index_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'is_email_domain_valid_for_store',
#    'has_docstring': True,
#    'docstring': 'Returns true if the email domain matches with a an already defined domain from the store identified by store_id',
#    'arguments': [{'name': 'store_id', 'type': 'int'},
#     {'name': 'email', 'type': 'str'},
#     {'name': 'cornershop_email', 'type': 'Optional[bool]'}],
#    'return_type': 'bool',
#    'score': 100.0},
#   {'name': 'localize_categories',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'categories', 'type': 'Iterable[Category]'},
#     {'name': 'language', 'type': 'Optional[str]'}],
#    'return_type': 'List[Category]',
#    'score': 67.0},
#   {'name': 'map_supply_product_with_catalog_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'sku_source', 'type': 'str'},
#     {'name': 'sku', 'type': 'str'},
#     {'name': 'catalog_product_id', 'type': 'int'}],
#    'return_type': 'SupplyProductData',
#    'score': 67.0},
#   {'name': 'mark_branch_as_unfeatureable',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch', 'type': 'StoreBranch'}],
#    'return_type': None,
#    'score': 67.0},
#   {'name': 'merge_product',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'barcode', 'type': 'missing'},
#     {'name': 'currency', 'type': 'missing'},
#     {'name': 'product_kwargs', 'type': 'missing'},
#     {'name': 'requester_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'process_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'file', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'process_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'file', 'type': 'missing'},
#     {'name': 'generate_branches', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'process_file',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'file', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'product_branch_is_found_constantly',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'reset_productbranch_availability_status_schedule',
#    'has_docstring': True,
#    'docstring': 'Resets the scheduled change of availability status for a product branch',
#    'arguments': [{'name': 'product_branch', 'type': 'ProductBranch'}],
#    'return_type': 'missing',
#    'score': 67.0},
#   {'name': 'save',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'schedule_productbranch_availability_status',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_branch', 'type': 'ProductBranch'},
#     {'name': 'availability_status', 'type': 'missing'},
#     {'name': 'scheduled_at', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 12.0},
#   {'name': 'schedules_updated_send_signal',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'schedules', 'type': 'list'},
#     {'name': 'old_times', 'type': 'dict'},
#     {'name': 'from_store', 'type': 'missing'}],
#    'return_type': None,
#    'score': 56.0},
#   {'name': 'search_multi_branch_products_grouped_by_categories',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'query', 'type': 'str'},
#     {'name': 'branch_ids', 'type': 'List[int]'},
#     {'name': 'user_id', 'type': 'int'},
#     {'name': 'parent_category_id', 'type': 'Optional[int]'},
#     {'name': 'sort_by', 'type': 'str'},
#     {'name': 'sort_asc', 'type': 'bool'},
#     {'name': 'context', 'type': 'Optional[Dict]'},
#     {'name': 'language', 'type': 'Optional[str]'}],
#    'return_type': 'List[Dict]',
#    'score': 67.0},
#   {'name': 'search_products_grouped_by_categories',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'query', 'type': 'str'},
#     {'name': 'branch_id', 'type': 'int'},
#     {'name': 'user_id', 'type': 'int'},
#     {'name': 'parent_category_id', 'type': 'Optional[int]'},
#     {'name': 'limit', 'type': 'int'},
#     {'name': 'sort_by', 'type': 'str'},
#     {'name': 'sort_asc', 'type': 'bool'},
#     {'name': 'context', 'type': 'Optional[Dict]'},
#     {'name': 'fuzzy', 'type': 'bool'},
#     {'name': 'language', 'type': 'Optional[str]'}],
#    'return_type': 'List[Dict]',
#    'score': 67.0},
#   {'name': 'select_area_covering_location',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'multi_poly', 'type': 'MultiPolygon'},
#     {'name': 'location', 'type': 'Point'}],
#    'return_type': 'MultiPolygon',
#    'score': 67.0},
#   {'name': 'set_branch_area',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch', 'type': 'missing'},
#     {'name': 'radius', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'set_branch_schedule_deactivation',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_branch', 'type': 'StoreBranch'},
#     {'name': 'area_schedule', 'type': 'AreaSchedule'},
#     {'name': 'today', 'type': 'date'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'set_parking_ticket_refundable_for_branch',
#    'has_docstring': True,
#    'docstring': 'Update or create parameter PARKING_TICKET_REFUNDABLE status(True/False) for a StoreBranch\nRaises:\n        HTTP_404_NOT_FOUND: If something goes wrong here, this exception will be raised',
#    'arguments': [{'name': 'store_branch_id', 'type': 'int'},
#     {'name': 'status', 'type': 'bool'}],
#    'return_type': 'missing',
#    'score': 67.0},
#   {'name': 'set_store_availability_area',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store', 'type': 'missing'},
#     {'name': 'city', 'type': 'missing'},
#     {'name': 'radius', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'simulate_total',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'missing'},
#     {'name': 'order_products', 'type': 'missing'},
#     {'name': 'context', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'store_branch_has_coming_schedules',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch_id', 'type': 'int'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'update_branch_areas_in_opzone',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'opzone_id', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'update_or_create_product_store',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'store_id', 'type': 'missing'},
#     {'name': 'product_id', 'type': 'missing'},
#     {'name': 'sku', 'type': 'missing'},
#     {'name': 'is_active', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'update_product_branch',
#    'has_docstring': True,
#    'docstring': 'Updates product branch availability status and branch price.\nOptionally, can schedule the change of the availability status',
#    'arguments': [{'name': 'product_branch', 'type': 'missing'},
#     {'name': 'availability', 'type': 'missing'},
#     {'name': 'price', 'type': 'missing'},
#     {'name': 'scheduled_at', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'update_product_image',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product_id', 'type': 'missing'},
#     {'name': 'image_file', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'update_store_branch_status',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'branch', 'type': 'StoreBranch'},
#     {'name': 'old_status', 'type': 'bool'},
#     {'name': 'new_status', 'type': 'bool'}],
#    'return_type': 'missing',
#    'score': 34.0},
#   {'name': 'upload_external_product_image',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'product', 'type': 'missing'},
#     {'name': 'image_url', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'user_has_flag',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'flag', 'type': 'missing'}],
#    'return_type': 'missing',
#    'score': 1.0},
#   {'name': 'write_day_schedule',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'data', 'type': 'list'},
#     {'name': 'row_index', 'type': 'int'},
#     {'name': 'row_column_index', 'type': 'int'},
#     {'name': 'step', 'type': 'int'}],
#    'return_type': 'missing',
#    'score': 28.5},
#   {'name': 'write_day_schedule',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'data', 'type': 'list'},
#     {'name': 'row_index', 'type': 'int'},
#     {'name': 'row_column_index', 'type': 'int'},
#     {'name': 'step', 'type': 'int'}],
#    'return_type': 'missing',
#    'score': 28.5},
#   {'name': 'write_headers',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'}],
#    'return_type': 'missing',
#    'score': 17.5},
#   {'name': 'write_headers',
#    'has_docstring': False,
#    'docstring': None,
#    'arguments': [{'name': 'self', 'type': 'missing'},
#     {'name': 'worksheet', 'type': 'Worksheet'},
#     {'name': 'date_list', 'type': 'list'}],
#    'return_type': 'missing',
#    'score': 23.0}],
#  'global': {'score': 53.676109215017064}}
